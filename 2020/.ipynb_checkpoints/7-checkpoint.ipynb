# %%
import re
from collections import defaultdict

# %% [markdown]
# Going to make a tree (well, a forest) with three fields
#
# color, parent (just color), children (number and color)
#
# and a dict for every color to the node in the tree
#
# Then, just find every node of that color, traverse to the root of that tree, and take the union of the root colors.

# %%
instructions = open('./inputs/7').read().split('\n')

# %%
instructions[:5]
# Out:
# ['drab plum bags contain 5 clear turquoise bags, 5 striped aqua bags, 4 dotted gold bags, 4 plaid chartreuse bags.',
#  'faded cyan bags contain 1 dim brown bag, 5 wavy magenta bags, 3 vibrant chartreuse bags, 4 muted fuchsia bags.',
#  'shiny brown bags contain 4 dark maroon bags.',
#  'bright plum bags contain 3 dull tomato bags, 5 bright tan bags, 4 plaid lime bags.',
#  'plaid purple bags contain 2 posh black bags.']

# %%
test = '''light red bags contain 1 bright white bag, 2 muted yellow bags.
dark orange bags contain 3 bright white bags, 4 muted yellow bags.
bright white bags contain 1 shiny gold bag.
muted yellow bags contain 2 shiny gold bags, 9 faded blue bags.
shiny gold bags contain 1 dark olive bag, 2 vibrant plum bags.
dark olive bags contain 3 faded blue bags, 4 dotted black bags.
vibrant plum bags contain 5 faded blue bags, 6 dotted black bags.
faded blue bags contain no other bags.
dotted black bags contain no other bags.'''

test_instructions = test.split('\n')

# %%
base_re = re.compile('(.*?)\sbags\scontain\s(.*)')

num_color_re = re.compile('(\d+)\s(.*)')

# %%
def get_bag_info(instructions):
    bag_info = dict()

    for i in instructions:
        m = base_re.match(i)
        base_color = m.group(1)

        rest = m.group(2).replace('.', '')

        inside = []

        if rest != 'no other bags':
            others = rest.split(', ')

            for other in others:
                other = other.replace(' bags', '').replace(' bag', '')
                m = num_color_re.match(other)

                num = int(m.group(1))
                color = m.group(2)

                inside.append((num, color))

        bag_info[base_color] = inside
    
    return bag_info

# %%
bag_info = get_bag_info(instructions)

# %% [markdown]
# Now build the tree

# %%
bag_info
# Out:
# {'drab plum': [(5, 'clear turquoise'),
#   (5, 'striped aqua'),
#   (4, 'dotted gold'),
#   (4, 'plaid chartreuse')],
#  'faded cyan': [(1, 'dim brown'),
#   (5, 'wavy magenta'),
#   (3, 'vibrant chartreuse'),
#   (4, 'muted fuchsia')],
#  'shiny brown': [(4, 'dark maroon')],
#  'bright plum': [(3, 'dull tomato'), (5, 'bright tan'), (4, 'plaid lime')],
#  'plaid purple': [(2, 'posh black')],
#  'wavy turquoise': [(1, 'wavy white'), (5, 'dotted maroon')],
#  'dotted aqua': [(4, 'dotted brown'), (4, 'dim plum')],
#  'drab chartreuse': [(2, 'dark olive')],
#  'vibrant black': [(5, 'mirrored black'),
#   (3, 'dark chartreuse'),
#   (2, 'muted salmon'),
#   (1, 'plaid coral')],
#  'posh purple': [(1, 'faded white'), (5, 'clear gray'), (4, 'clear silver')],
#  'drab coral': [(5, 'dark salmon')],
#  'wavy silver': [(5, 'dotted turquoise'),
#   (3, 'dark bronze'),
#   (1, 'muted silver')],
#  'plaid silver': [(2, 'plaid tomato')],
#  'dark olive': [(5, 'faded olive'),
#   (5, 'dull chartreuse'),
#   (1, 'pale gold'),
#   (3, 'dull tomato')],
#  'mirrored lime': [(3, 'dull purple'), (4, 'light teal')],
#  'bright green': [(2, 'pale tan'), (5, 'drab tan')],
#  'posh lavender': [(4, 'posh indigo'), (5, 'mirrored brown')],
#  'muted purple': [(2, 'posh chartreuse'),
#   (3, 'faded lime'),
#   (3, 'dim chartreuse'),
#   (2, 'striped fuchsia')],
#  'drab gray': [(1, 'striped indigo'), (2, 'dim coral')],
#  'posh olive': [(1, 'dim tomato'), (4, 'light gray')],
#  'posh yellow': [(2, 'posh purple')],
#  'clear cyan': [(1, 'dotted lime'), (4, 'dark bronze'), (5, 'wavy lime')],
#  'clear olive': [(2, 'drab coral'),
#   (2, 'bright olive'),
#   (3, 'vibrant indigo'),
#   (1, 'bright cyan')],
#  'dotted brown': [(2, 'muted tomato')],
#  'dim lime': [(1, 'posh purple'),
#   (3, 'pale gold'),
#   (3, 'light silver'),
#   (1, 'dotted turquoise')],
#  'drab aqua': [(4, 'dim olive'), (1, 'light gray')],
#  'wavy beige': [(2, 'striped indigo'),
#   (4, 'faded crimson'),
#   (4, 'posh coral')],
#  'pale olive': [(1, 'muted blue')],
#  'drab teal': [(2, 'vibrant lime'),
#   (3, 'light turquoise'),
#   (5, 'bright lavender')],
#  'striped fuchsia': [(3, 'bright teal'), (5, 'dim bronze'), (3, 'faded cyan')],
#  'dark red': [(3, 'vibrant gold'), (5, 'faded bronze')],
#  'posh cyan': [(2, 'light tan')],
#  'light salmon': [(2, 'plaid beige'),
#   (2, 'dull chartreuse'),
#   (1, 'faded beige')],
#  'clear indigo': [(4, 'plaid olive'),
#   (1, 'pale brown'),
#   (3, 'shiny fuchsia'),
#   (4, 'dotted tomato')],
#  'shiny olive': [(5, 'dotted lavender'),
#   (5, 'bright maroon'),
#   (5, 'faded maroon')],
#  'muted blue': [(1, 'dull violet')],
#  'bright red': [(2, 'dull bronze'),
#   (3, 'pale lime'),
#   (1, 'vibrant brown'),
#   (5, 'muted magenta')],
#  'pale violet': [(4, 'pale plum')],
#  'muted bronze': [(2, 'mirrored gold'),
#   (4, 'plaid crimson'),
#   (4, 'light cyan')],
#  'dim gray': [(4, 'dim tomato'), (5, 'wavy magenta')],
#  'shiny crimson': [(5, 'muted brown')],
#  'dim indigo': [(3, 'striped beige'), (3, 'clear gold'), (2, 'bright gray')],
#  'dotted turquoise': [(2, 'striped red')],
#  'striped tan': [(3, 'light yellow')],
#  'muted brown': [(3, 'posh black'),
#   (3, 'striped brown'),
#   (5, 'light gray'),
#   (2, 'clear white')],
#  'clear blue': [(2, 'plaid gold'), (5, 'mirrored white')],
#  'wavy purple': [(1, 'wavy magenta'),
#   (1, 'muted aqua'),
#   (3, 'dim gray'),
#   (1, 'dim tomato')],
#  'striped magenta': [(2, 'pale fuchsia'),
#   (4, 'light cyan'),
#   (2, 'shiny fuchsia')],
#  'dotted teal': [(1, 'mirrored blue'),
#   (1, 'posh plum'),
#   (2, 'dull violet'),
#   (4, 'dotted brown')],
#  'drab lavender': [(5, 'pale yellow'), (1, 'clear silver')],
#  'dull beige': [(4, 'clear chartreuse'), (4, 'drab gray')],
#  'faded indigo': [(1, 'pale cyan')],
#  'plaid chartreuse': [(4, 'muted aqua'), (3, 'dim coral'), (3, 'pale gold')],
#  'dull fuchsia': [(5, 'pale maroon'), (2, 'mirrored bronze')],
#  'drab white': [(4, 'dull orange')],
#  'dark maroon': [(5, 'dim lavender')],
#  'pale black': [(2, 'wavy silver')],
#  'pale bronze': [(4, 'dim salmon'),
#   (5, 'vibrant lavender'),
#   (4, 'vibrant crimson'),
#   (1, 'bright crimson')],
#  'mirrored cyan': [(3, 'pale lavender'), (5, 'dull silver')],
#  'dotted green': [(1, 'bright yellow'),
#   (5, 'drab fuchsia'),
#   (5, 'posh orange'),
#   (5, 'mirrored blue')],
#  'plaid green': [(1, 'wavy tan'), (2, 'clear chartreuse')],
#  'drab beige': [(3, 'dotted lime'), (4, 'clear brown'), (2, 'dotted salmon')],
#  'light turquoise': [(3, 'dotted tomato'),
#   (1, 'muted silver'),
#   (4, 'striped brown')],
#  'light crimson': [(2, 'dark aqua'),
#   (4, 'bright violet'),
#   (1, 'mirrored olive'),
#   (4, 'mirrored violet')],
#  'wavy maroon': [(2, 'dull teal'),
#   (2, 'pale violet'),
#   (5, 'bright aqua'),
#   (2, 'faded tan')],
#  'dark coral': [(5, 'striped black')],
#  'faded orange': [(3, 'clear silver'), (2, 'vibrant tomato')],
#  'dotted olive': [(5, 'clear gray'),
#   (5, 'striped indigo'),
#   (5, 'dim gray'),
#   (5, 'posh plum')],
#  'shiny salmon': [(2, 'wavy fuchsia'), (4, 'striped gold'), (5, 'wavy coral')],
#  'wavy red': [(1, 'clear silver'),
#   (5, 'dotted beige'),
#   (1, 'pale cyan'),
#   (4, 'dim beige')],
#  'light gray': [(3, 'dim coral'),
#   (5, 'striped indigo'),
#   (2, 'bright lime'),
#   (4, 'vibrant magenta')],
#  'muted chartreuse': [(2, 'dim tomato'),
#   (5, 'dim coral'),
#   (3, 'pale yellow'),
#   (5, 'drab gray')],
#  'pale turquoise': [(2, 'light gray'),
#   (3, 'faded salmon'),
#   (4, 'drab white'),
#   (3, 'plaid olive')],
#  'striped turquoise': [(3, 'pale plum')],
#  'drab cyan': [(3, 'wavy indigo'), (3, 'clear white')],
#  'dark magenta': [(3, 'muted blue')],
#  'faded gray': [(1, 'muted green'),
#   (5, 'posh coral'),
#   (3, 'wavy magenta'),
#   (4, 'light beige')],
#  'posh crimson': [(1, 'faded lavender')],
#  'faded green': [(4, 'mirrored red'),
#   (5, 'plaid beige'),
#   (2, 'shiny maroon'),
#   (3, 'mirrored lime')],
#  'mirrored silver': [(2, 'wavy gold'), (1, 'clear beige')],
#  'shiny aqua': [(1, 'bright teal'), (4, 'wavy tan')],
#  'plaid lime': [(2, 'striped indigo')],
#  'clear beige': [(5, 'dim tomato'),
#   (2, 'plaid olive'),
#   (2, 'dark crimson'),
#   (5, 'dull turquoise')],
#  'striped beige': [(2, 'bright white'),
#   (1, 'pale cyan'),
#   (3, 'dark bronze'),
#   (3, 'vibrant gray')],
#  'dark indigo': [(2, 'striped plum')],
#  'wavy coral': [(4, 'posh cyan'), (3, 'muted fuchsia')],
#  'plaid gray': [(2, 'clear maroon'), (3, 'wavy beige'), (3, 'light lime')],
#  'dim yellow': [(2, 'dotted olive'),
#   (5, 'wavy magenta'),
#   (2, 'mirrored tomato')],
#  'plaid fuchsia': [(3, 'dotted white'), (1, 'dull purple')],
#  'bright violet': [(1, 'shiny lavender'),
#   (3, 'dotted tomato'),
#   (4, 'dotted white'),
#   (3, 'mirrored olive')],
#  'light cyan': [(2, 'posh black')],
#  'shiny orange': [(2, 'dull purple'),
#   (1, 'dotted maroon'),
#   (2, 'dull indigo'),
#   (4, 'drab gold')],
#  'pale purple': [(1, 'dotted magenta'),
#   (3, 'drab red'),
#   (1, 'posh lime'),
#   (4, 'muted turquoise')],
#  'dim brown': [(3, 'dull coral'),
#   (1, 'dark tan'),
#   (1, 'pale red'),
#   (3, 'clear chartreuse')],
#  'shiny maroon': [(3, 'mirrored indigo')],
#  'pale tomato': [(2, 'drab gray'), (3, 'shiny lavender'), (4, 'clear silver')],
#  'vibrant magenta': [],
#  'plaid indigo': [(4, 'dotted black'), (1, 'vibrant aqua')],
#  'striped chartreuse': [(2, 'pale orange'),
#   (5, 'pale maroon'),
#   (2, 'dim lime')],
#  'dim coral': [],
#  'mirrored yellow': [(4, 'dotted tan'), (1, 'dull blue')],
#  'clear lime': [(4, 'striped violet'),
#   (3, 'striped chartreuse'),
#   (5, 'drab crimson')],
#  'bright salmon': [(2, 'shiny plum'), (5, 'faded white')],
#  'light green': [(5, 'mirrored bronze'), (4, 'dull chartreuse')],
#  'vibrant beige': [(4, 'striped brown'),
#   (4, 'muted blue'),
#   (5, 'shiny crimson')],
#  'plaid tan': [(3, 'pale blue'), (5, 'light gray'), (3, 'posh tomato')],
#  'dull aqua': [(4, 'muted blue')],
#  'wavy green': [(4, 'drab orange'),
#   (2, 'vibrant yellow'),
#   (5, 'faded beige'),
#   (3, 'dotted turquoise')],
#  'muted yellow': [(5, 'pale magenta'), (5, 'striped plum')],
#  'mirrored tomato': [(3, 'pale salmon'),
#   (4, 'shiny lavender'),
#   (1, 'dark bronze'),
#   (2, 'pale blue')],
#  'drab fuchsia': [(5, 'mirrored purple')],
#  'drab olive': [(3, 'wavy violet'), (3, 'light tan'), (4, 'pale brown')],
#  'faded brown': [(2, 'light crimson')],
#  'vibrant white': [(2, 'pale tomato'),
#   (4, 'dotted turquoise'),
#   (3, 'pale blue')],
#  'dotted yellow': [(3, 'clear chartreuse'),
#   (5, 'drab cyan'),
#   (5, 'striped magenta')],
#  'posh coral': [(4, 'light tan'), (4, 'pale brown')],
#  'drab gold': [(2, 'light tan'), (4, 'clear white')],
#  'mirrored purple': [(3, 'shiny gold')],
#  'posh green': [(4, 'wavy indigo'),
#   (1, 'dark crimson'),
#   (1, 'muted brown'),
#   (1, 'light gray')],
#  'bright maroon': [(5, 'dotted silver')],
#  'dim chartreuse': [(4, 'faded olive')],
#  'bright coral': [(2, 'bright olive'), (2, 'light silver')],
#  'striped gold': [(1, 'dotted maroon'), (4, 'posh maroon'), (1, 'pale gold')],
#  'light chartreuse': [(3, 'plaid blue'), (4, 'shiny gold'), (4, 'dull teal')],
#  'clear salmon': [(5, 'plaid blue'),
#   (3, 'muted cyan'),
#   (1, 'mirrored tomato')],
#  'wavy blue': [(2, 'drab turquoise'),
#   (5, 'vibrant purple'),
#   (3, 'faded indigo'),
#   (2, 'bright green')],
#  'dark beige': [(4, 'faded crimson'), (3, 'dim silver'), (4, 'plaid green')],
#  'bright gold': [(1, 'striped indigo'), (2, 'dark salmon')],
#  'posh bronze': [(3, 'dim gray')],
#  'mirrored lavender': [(4, 'striped maroon'),
#   (5, 'light blue'),
#   (2, 'wavy coral'),
#   (4, 'faded crimson')],
#  'pale tan': [(3, 'vibrant beige'),
#   (1, 'dark crimson'),
#   (1, 'drab brown'),
#   (1, 'bright olive')],
#  'mirrored coral': [(1, 'clear white'),
#   (5, 'dotted beige'),
#   (2, 'dull violet')],
#  'striped white': [(3, 'vibrant gold'),
#   (1, 'vibrant crimson'),
#   (5, 'muted indigo'),
#   (4, 'clear gold')],
#  'plaid white': [(3, 'light gray'),
#   (5, 'drab turquoise'),
#   (5, 'dark lavender')],
#  'clear brown': [(1, 'striped indigo'),
#   (1, 'muted cyan'),
#   (3, 'striped tomato'),
#   (2, 'bright cyan')],
#  'pale beige': [(2, 'bright fuchsia'),
#   (2, 'dotted fuchsia'),
#   (3, 'mirrored black'),
#   (3, 'dull gold')],
#  'shiny lavender': [(5, 'clear white'), (3, 'striped brown')],
#  'posh salmon': [(4, 'mirrored plum'),
#   (1, 'dotted purple'),
#   (1, 'striped gray'),
#   (1, 'bright green')],
#  'posh magenta': [(4, 'dark gray'),
#   (3, 'shiny fuchsia'),
#   (5, 'dotted tomato'),
#   (2, 'posh yellow')],
#  'striped yellow': [(2, 'faded white'),
#   (1, 'dotted lavender'),
#   (2, 'posh coral'),
#   (1, 'light yellow')],
#  'bright tomato': [(4, 'shiny plum'),
#   (4, 'dotted olive'),
#   (4, 'clear purple'),
#   (2, 'dotted plum')],
#  'mirrored turquoise': [(2, 'wavy beige'),
#   (2, 'dim gray'),
#   (5, 'dark indigo')],
#  'vibrant lavender': [(3, 'pale magenta'),
#   (2, 'shiny coral'),
#   (4, 'drab white'),
#   (5, 'vibrant white')],
#  'faded magenta': [(1, 'plaid lavender'), (2, 'drab teal'), (5, 'dull beige')],
#  'dark yellow': [(1, 'mirrored gold'),
#   (2, 'dark lavender'),
#   (3, 'striped indigo')],
#  'posh silver': [(1, 'dull purple'), (2, 'plaid olive'), (3, 'striped red')],
#  'dull green': [(4, 'striped crimson'), (5, 'dim coral'), (3, 'vibrant aqua')],
#  'dotted black': [(4, 'posh plum'),
#   (1, 'muted blue'),
#   (4, 'shiny beige'),
#   (1, 'dotted lime')],
#  'light yellow': [(5, 'muted tomato'),
#   (3, 'muted fuchsia'),
#   (5, 'posh maroon')],
#  'wavy black': [(3, 'bright white'), (2, 'bright lavender')],
#  'muted crimson': [(1, 'dark crimson'),
#   (4, 'pale salmon'),
#   (4, 'striped red'),
#   (2, 'dim tomato')],
#  'shiny yellow': [(5, 'posh salmon'), (3, 'dotted olive')],
#  'striped olive': [(1, 'light black'),
#   (1, 'mirrored olive'),
#   (1, 'dull purple'),
#   (2, 'light orange')],
#  'light silver': [(4, 'clear silver'),
#   (4, 'mirrored black'),
#   (2, 'clear gray')],
#  'dull indigo': [(2, 'muted lime')],
#  'muted indigo': [(4, 'posh lime'), (4, 'dull white')],
#  'posh red': [(2, 'posh cyan'), (2, 'dull brown'), (5, 'drab maroon')],
#  'plaid brown': [(3, 'clear silver'),
#   (5, 'dim beige'),
#   (3, 'dim lime'),
#   (4, 'striped blue')],
#  'pale green': [(2, 'shiny bronze'),
#   (3, 'mirrored plum'),
#   (4, 'light yellow')],
#  'plaid maroon': [(5, 'plaid cyan'), (1, 'drab white')],
#  'dim teal': [(4, 'posh maroon'), (1, 'dull gold'), (4, 'muted coral')],
#  'clear lavender': [(5, 'striped brown'), (3, 'posh plum')],
#  'bright yellow': [(5, 'clear tan'), (2, 'striped salmon')],
#  'clear fuchsia': [(3, 'clear coral'), (4, 'muted aqua')],
#  'muted maroon': [(3, 'dotted fuchsia')],
#  'dark plum': [(3, 'dotted tomato'),
#   (5, 'clear violet'),
#   (3, 'vibrant magenta')],
#  'bright magenta': [(2, 'plaid tan'),
#   (4, 'dotted purple'),
#   (3, 'wavy indigo')],
#  'dull plum': [(3, 'muted crimson'), (4, 'mirrored green')],
#  'dull black': [(3, 'muted chartreuse'), (1, 'posh cyan'), (4, 'bright gray')],
#  'posh orange': [(5, 'striped violet')],
#  'vibrant teal': [(3, 'bright red'), (1, 'wavy indigo'), (3, 'pale brown')],
#  'pale gold': [],
#  'faded plum': [(2, 'striped plum'),
#   (3, 'wavy maroon'),
#   (5, 'vibrant bronze'),
#   (4, 'clear green')],
#  'shiny coral': [(5, 'dull white'), (1, 'clear tan'), (3, 'shiny beige')],
#  'bright lavender': [(2, 'bright lime')],
#  'shiny indigo': [(4, 'dull coral'), (5, 'posh coral')],
#  'muted turquoise': [(5, 'drab crimson'),
#   (4, 'drab teal'),
#   (3, 'vibrant bronze')],
#  'pale plum': [(2, 'dull beige'), (3, 'dotted turquoise')],
#  'dull gray': [(3, 'bright salmon')],
#  'vibrant indigo': [(2, 'mirrored bronze'), (3, 'light orange')],
#  'light lime': [(4, 'drab coral')],
#  'pale magenta': [(3, 'dark crimson')],
#  'clear aqua': [(2, 'plaid olive'), (4, 'muted indigo')],
#  'light gold': [(4, 'vibrant white'),
#   (5, 'faded lime'),
#   (3, 'striped brown'),
#   (5, 'dim coral')],
#  'dull crimson': [(3, 'dim olive'),
#   (4, 'dim turquoise'),
#   (1, 'muted fuchsia')],
#  'clear gray': [(3, 'clear white'),
#   (4, 'dark crimson'),
#   (4, 'dotted plum'),
#   (3, 'light gray')],
#  'dotted tomato': [(5, 'mirrored blue'), (3, 'dotted crimson')],
#  'bright indigo': [(3, 'wavy lime'), (5, 'dark bronze'), (4, 'shiny brown')],
#  'light lavender': [(1, 'dim fuchsia')],
#  'clear purple': [(4, 'dark red'), (3, 'clear turquoise')],
#  'dark lavender': [(5, 'vibrant crimson'),
#   (1, 'vibrant white'),
#   (3, 'dull purple'),
#   (1, 'plaid tan')],
#  'vibrant green': [(2, 'wavy teal'),
#   (2, 'dull orange'),
#   (5, 'plaid coral'),
#   (2, 'striped yellow')],
#  'faded maroon': [(1, 'muted tomato'), (3, 'pale gold'), (2, 'muted fuchsia')],
#  'light tomato': [(3, 'shiny fuchsia'), (4, 'dull turquoise')],
#  'light olive': [(4, 'dotted indigo'), (3, 'pale coral')],
#  'faded blue': [(2, 'light gray'),
#   (3, 'muted brown'),
#   (5, 'dim coral'),
#   (1, 'light tan')],
#  'mirrored white': [(1, 'posh cyan')],
#  'dull bronze': [(5, 'clear lavender'),
#   (4, 'bright olive'),
#   (4, 'dull brown'),
#   (2, 'striped black')],
#  'vibrant coral': [(2, 'dim coral'), (2, 'faded blue'), (2, 'drab cyan')],
#  'bright lime': [],
#  'wavy crimson': [(1, 'dim indigo')],
#  'vibrant blue': [(2, 'posh gold'),
#   (3, 'mirrored tan'),
#   (3, 'muted green'),
#   (5, 'faded beige')],
#  'light orange': [(5, 'posh black'), (2, 'dull brown')],
#  'striped indigo': [],
#  'faded lime': [(2, 'dull violet'), (2, 'shiny lavender')],
#  'dim bronze': [(4, 'mirrored blue')],
#  'pale coral': [(2, 'clear magenta'), (4, 'clear gold')],
#  'wavy fuchsia': [(3, 'muted olive'), (1, 'dull violet')],
#  'mirrored indigo': [(1, 'clear magenta'),
#   (3, 'mirrored beige'),
#   (3, 'bright violet')],
#  'plaid turquoise': [(2, 'muted turquoise')],
#  'dull blue': [(2, 'dotted white'), (5, 'mirrored green')],
#  'posh white': [(2, 'pale teal'),
#   (4, 'pale green'),
#   (5, 'dim bronze'),
#   (5, 'mirrored cyan')],
#  'mirrored teal': [(2, 'plaid blue'), (1, 'drab crimson')],
#  'clear silver': [(5, 'striped indigo'),
#   (2, 'dim plum'),
#   (5, 'muted aqua'),
#   (5, 'light tan')],
#  'dull lime': [(2, 'plaid crimson'), (5, 'light cyan'), (1, 'dotted crimson')],
#  'dull yellow': [(3, 'plaid aqua'), (2, 'dim red')],
#  'mirrored olive': [(4, 'faded blue'),
#   (2, 'posh purple'),
#   (1, 'striped brown')],
#  'vibrant fuchsia': [(2, 'light black'), (2, 'vibrant salmon')],
#  'mirrored black': [(4, 'posh cyan'), (1, 'wavy indigo')],
#  'pale yellow': [(2, 'faded blue'),
#   (5, 'muted fuchsia'),
#   (2, 'striped brown')],
#  'pale fuchsia': [(1, 'drab silver'),
#   (2, 'clear silver'),
#   (2, 'shiny lavender')],
#  'drab turquoise': [(5, 'drab cyan'), (5, 'plaid cyan'), (3, 'wavy tan')],
#  'vibrant red': [(4, 'mirrored beige'),
#   (2, 'wavy magenta'),
#   (1, 'light cyan')],
#  'striped red': [],
#  'vibrant brown': [(1, 'dotted tomato'),
#   (3, 'vibrant magenta'),
#   (2, 'striped beige'),
#   (4, 'dull brown')],
#  'faded chartreuse': [(4, 'light gray'),
#   (5, 'striped salmon'),
#   (5, 'dark salmon'),
#   (3, 'dull orange')],
#  'mirrored tan': [(4, 'clear chartreuse')],
#  'light tan': [],
#  'dim blue': [(2, 'dull white')],
#  'posh tomato': [(3, 'dull indigo'), (2, 'striped red')],
#  'bright blue': [(3, 'shiny crimson'),
#   (4, 'muted brown'),
#   (3, 'dotted magenta'),
#   (2, 'pale salmon')],
#  'faded gold': [(3, 'clear white'),
#   (2, 'dotted turquoise'),
#   (5, 'light orange')],
#  'plaid orange': [(1, 'clear black'),
#   (3, 'striped red'),
#   (4, 'dark turquoise'),
#   (4, 'dull coral')],
#  'shiny tan': [(3, 'dotted coral'), (3, 'posh orange'), (5, 'vibrant tan')],
#  'clear plum': [(5, 'dim beige'),
#   (1, 'pale gray'),
#   (1, 'clear purple'),
#   (5, 'posh coral')],
#  'bright turquoise': [(2, 'plaid orange')],
#  'dotted plum': [(5, 'faded olive'), (5, 'clear white')],
#  'shiny green': [(4, 'drab maroon'), (2, 'drab purple')],
#  'plaid tomato': [(1, 'vibrant tomato'),
#   (2, 'posh coral'),
#   (3, 'faded beige'),
#   (2, 'faded chartreuse')],
#  'wavy lime': [(4, 'striped olive'), (1, 'vibrant beige')],
#  'striped brown': [(4, 'drab gray'),
#   (2, 'clear white'),
#   (3, 'bright lime'),
#   (3, 'vibrant magenta')],
#  'dark orange': [(1, 'wavy silver'),
#   (5, 'muted magenta'),
#   (1, 'dim yellow'),
#   (1, 'vibrant purple')],
#  'dotted magenta': [(1, 'mirrored purple')],
#  'bright black': [(5, 'shiny aqua')],
#  'clear green': [(4, 'vibrant gold'), (4, 'pale gold')],
#  'drab indigo': [(1, 'bright coral'),
#   (5, 'plaid tomato'),
#   (3, 'muted chartreuse')],
#  'shiny fuchsia': [(5, 'dim lavender'),
#   (2, 'light teal'),
#   (4, 'dim lime'),
#   (3, 'wavy purple')],
#  'vibrant crimson': [(1, 'dim lavender'),
#   (5, 'dark tan'),
#   (1, 'dotted turquoise'),
#   (2, 'striped red')],
#  'clear red': [(5, 'wavy magenta'), (2, 'bright plum')],
#  'dotted red': [(3, 'pale cyan')],
#  'striped black': [(3, 'pale red'), (1, 'clear beige'), (3, 'dull coral')],
#  'plaid crimson': [(4, 'wavy violet'), (1, 'clear gray')],
#  'muted silver': [(1, 'muted chartreuse'),
#   (2, 'shiny bronze'),
#   (1, 'striped brown'),
#   (1, 'posh coral')],
#  'drab green': [(1, 'faded white'),
#   (5, 'posh orange'),
#   (2, 'dim magenta'),
#   (3, 'wavy purple')],
#  'vibrant olive': [(5, 'dark yellow'),
#   (1, 'pale black'),
#   (1, 'drab olive'),
#   (5, 'shiny gold')],
#  'bright cyan': [(2, 'dim tomato'),
#   (2, 'plaid brown'),
#   (1, 'bright plum'),
#   (5, 'drab lavender')],
#  'dotted blue': [(2, 'pale tan'),
#   (1, 'striped green'),
#   (2, 'striped lime'),
#   (3, 'shiny tomato')],
#  'faded yellow': [(3, 'posh maroon'), (1, 'dull tomato'), (2, 'pale cyan')],
#  'dark black': [(3, 'shiny purple'), (2, 'clear violet'), (5, 'wavy brown')],
#  'vibrant bronze': [(5, 'pale salmon')],
#  'wavy chartreuse': [(1, 'posh turquoise'),
#   (1, 'vibrant silver'),
#   (3, 'plaid teal'),
#   (1, 'dotted salmon')],
#  'faded black': [(1, 'light tan'), (1, 'faded beige')],
#  'dim beige': [(3, 'muted fuchsia'),
#   (5, 'striped plum'),
#   (1, 'faded violet'),
#   (5, 'clear chartreuse')],
#  'striped plum': [(1, 'posh black'), (2, 'plaid lime'), (4, 'clear white')],
#  'dotted silver': [(2, 'vibrant gray'),
#   (5, 'clear white'),
#   (2, 'vibrant tomato')],
#  'dull salmon': [(4, 'pale plum'), (2, 'pale magenta'), (1, 'light gray')],
#  'pale maroon': [(3, 'vibrant white')],
#  'light blue': [(3, 'mirrored maroon')],
#  'striped aqua': [(5, 'dark purple'),
#   (1, 'striped green'),
#   (4, 'mirrored coral')],
#  'mirrored beige': [(1, 'shiny fuchsia'), (1, 'dim plum')],
#  'pale aqua': [(5, 'mirrored green')],
#  'dim red': [(2, 'mirrored maroon'),
#   (4, 'dotted yellow'),
#   (5, 'dim tomato'),
#   (4, 'faded silver')],
#  'light bronze': [(1, 'dim orange'),
#   (1, 'posh tomato'),
#   (5, 'mirrored white')],
#  'plaid coral': [(5, 'vibrant tomato'),
#   (5, 'pale bronze'),
#   (3, 'dotted turquoise'),
#   (2, 'drab brown')],
#  'dull violet': [(2, 'muted chartreuse')],
#  'wavy teal': [(3, 'shiny plum'), (5, 'dark lavender')],
#  'wavy cyan': [(5, 'faded red'),
#   (4, 'light bronze'),
#   (5, 'shiny bronze'),
#   (4, 'dull silver')],
#  'faded olive': [(4, 'wavy magenta'), (1, 'striped red')],
#  'drab tomato': [(5, 'plaid cyan'),
#   (1, 'plaid chartreuse'),
#   (1, 'dim tomato')],
#  'clear chartreuse': [(4, 'striped brown'), (2, 'plaid lime')],
#  'dull olive': [(1, 'dull purple'), (2, 'plaid yellow')],
#  'dim silver': [(3, 'pale tomato'), (1, 'plaid chartreuse')],
#  'dotted coral': [(5, 'pale salmon'),
#   (4, 'dim coral'),
#   (4, 'striped fuchsia'),
#   (2, 'dim turquoise')],
#  'bright fuchsia': [(4, 'light gold'),
#   (3, 'shiny crimson'),
#   (3, 'clear white')],
#  'bright brown': [(1, 'vibrant tomato'), (2, 'wavy teal'), (3, 'dotted red')],
#  'striped cyan': [(3, 'bright lime')],
#  'clear turquoise': [(5, 'mirrored maroon')],
#  'posh brown': [(5, 'vibrant silver'), (4, 'bright lime')],
#  'wavy aqua': [(4, 'wavy indigo'), (1, 'faded crimson'), (4, 'drab indigo')],
#  'pale chartreuse': [(2, 'faded salmon')],
#  'clear gold': [(2, 'faded turquoise'), (1, 'shiny magenta')],
#  'muted beige': [(5, 'mirrored indigo'), (1, 'clear violet')],
#  'light white': [(1, 'vibrant magenta')],
#  'muted cyan': [(2, 'plaid white'),
#   (5, 'mirrored black'),
#   (4, 'pale gold'),
#   (5, 'drab magenta')],
#  'muted teal': [(1, 'pale orange')],
#  'vibrant cyan': [(2, 'dotted magenta'), (1, 'clear tan')],
#  'wavy white': [(1, 'faded blue')],
#  'striped silver': [(5, 'light crimson'),
#   (4, 'clear salmon'),
#   (1, 'shiny green')],
#  'shiny teal': [(1, 'wavy coral')],
#  'dim black': [(3, 'vibrant silver'),
#   (1, 'clear maroon'),
#   (4, 'bright chartreuse')],
#  'dim plum': [(2, 'posh coral'), (3, 'dark crimson'), (1, 'drab olive')],
#  'wavy bronze': [(2, 'faded olive'), (2, 'dim red'), (2, 'pale brown')],
#  'dim turquoise': [(3, 'dull teal'),
#   (5, 'shiny bronze'),
#   (2, 'striped orange'),
#   (1, 'dim fuchsia')],
#  'posh lime': [(4, 'muted tomato'), (3, 'muted brown'), (1, 'bright olive')],
#  'shiny cyan': [(3, 'faded purple'),
#   (5, 'wavy chartreuse'),
#   (4, 'shiny maroon')],
#  'pale blue': [(2, 'striped turquoise'), (2, 'dull turquoise')],
#  'muted black': [(4, 'pale turquoise'),
#   (4, 'pale beige'),
#   (4, 'mirrored black')],
#  'posh gold': [(1, 'light brown'), (4, 'posh yellow'), (5, 'dim violet')],
#  'plaid olive': [],
#  'dotted beige': [(4, 'clear tan'),
#   (1, 'shiny fuchsia'),
#   (3, 'posh green'),
#   (4, 'wavy purple')],
#  'dull magenta': [(3, 'muted lime'), (5, 'mirrored blue')],
#  'striped green': [(5, 'light cyan')],
#  'dark white': [(2, 'wavy yellow'), (5, 'dim salmon'), (2, 'bright green')],
#  'muted lavender': [(3, 'dotted teal'),
#   (5, 'dotted bronze'),
#   (2, 'mirrored lime'),
#   (5, 'dim fuchsia')],
#  'dotted indigo': [(5, 'drab chartreuse'),
#   (1, 'dim lime'),
#   (3, 'plaid white'),
#   (2, 'shiny plum')],
#  'light indigo': [(5, 'bright tan')],
#  'faded turquoise': [(3, 'faded cyan'),
#   (4, 'dull salmon'),
#   (3, 'dark bronze')],
#  'mirrored magenta': [(1, 'clear turquoise'), (4, 'wavy plum')],
#  'dull brown': [(5, 'dim tomato')],
#  'plaid aqua': [(4, 'bright teal'),
#   (3, 'dim gray'),
#   (3, 'clear crimson'),
#   (5, 'clear chartreuse')],
#  'drab red': [(2, 'plaid purple'), (3, 'muted silver')],
#  'wavy plum': [(3, 'wavy indigo'), (3, 'posh cyan')],
#  'bright aqua': [(1, 'dim magenta')],
#  'dotted violet': [(4, 'light orange')],
#  'wavy salmon': [(3, 'wavy turquoise'),
#   (1, 'dark lavender'),
#   (3, 'striped silver'),
#   (3, 'posh coral')],
#  'posh beige': [(1, 'pale black')],
#  'clear bronze': [(4, 'clear teal'), (3, 'dim crimson')],
#  'pale teal': [(1, 'dark bronze'), (4, 'plaid maroon'), (4, 'light magenta')],
#  'mirrored violet': [(2, 'clear beige')],
#  'drab blue': [(1, 'faded yellow')],
#  'light violet': [(4, 'plaid aqua')],
#  'vibrant chartreuse': [(1, 'mirrored beige')],
#  'pale salmon': [(5, 'drab gray'), (3, 'muted brown'), (2, 'dotted plum')],
#  'plaid violet': [(5, 'muted blue'), (4, 'wavy black')],
#  'bright tan': [(1, 'bright white'), (4, 'posh cyan')],
#  'vibrant purple': [(2, 'dark plum'), (4, 'bright brown')],
#  'drab tan': [(5, 'dull orange'), (4, 'plaid fuchsia')],
#  'dotted tan': [(2, 'drab violet'),
#   (1, 'light turquoise'),
#   (2, 'clear indigo')],
#  'vibrant maroon': [(1, 'drab silver'), (1, 'plaid plum')],
#  'dull white': [(2, 'dotted crimson'),
#   (1, 'light orange'),
#   (2, 'dark lavender'),
#   (5, 'plaid blue')],
#  'wavy orange': [(1, 'shiny fuchsia'), (2, 'clear lavender')],
#  'faded fuchsia': [(2, 'dim purple'), (4, 'muted yellow'), (3, 'muted brown')],
#  'dim tan': [(1, 'shiny purple'),
#   (5, 'wavy magenta'),
#   (4, 'faded beige'),
#   (2, 'vibrant lime')],
#  'bright white': [(1, 'dim plum'), (1, 'light gray'), (2, 'muted fuchsia')],
#  'pale lavender': [(2, 'faded lime'), (1, 'faded tan'), (3, 'dotted maroon')],
#  'dim fuchsia': [(2, 'clear lavender'),
#   (5, 'dotted red'),
#   (3, 'vibrant chartreuse')],
#  'pale silver': [(5, 'posh black')],
#  'faded salmon': [(4, 'light white'),
#   (2, 'plaid brown'),
#   (3, 'vibrant yellow')],
#  'faded bronze': [(5, 'mirrored white'),
#   (5, 'striped plum'),
#   (4, 'dim magenta'),
#   (2, 'faded lime')],
#  'shiny gray': [(1, 'striped salmon'), (3, 'clear crimson')],
#  'drab lime': [(5, 'light crimson')],
#  'bright orange': [(4, 'plaid tomato'), (1, 'mirrored bronze')],
#  'dark crimson': [(5, 'striped red')],
#  'dull teal': [(4, 'wavy indigo'),
#   (1, 'drab brown'),
#   (3, 'light cyan'),
#   (4, 'dotted gold')],
#  'light maroon': [(2, 'bright violet'),
#   (2, 'dim gray'),
#   (3, 'shiny turquoise')],
#  'faded coral': [(4, 'dark teal')],
#  'shiny bronze': [(3, 'pale salmon'), (3, 'pale plum')],
#  'dim violet': [(3, 'vibrant magenta'), (4, 'shiny bronze')],
#  'pale red': [(5, 'drab silver')],
#  'dark tomato': [(4, 'shiny lime'),
#   (5, 'wavy purple'),
#   (4, 'shiny blue'),
#   (5, 'drab gold')],
#  'dull gold': [(5, 'light olive'), (1, 'light gray')],
#  'posh tan': [(4, 'dull gold'),
#   (3, 'vibrant turquoise'),
#   (2, 'plaid aqua'),
#   (5, 'dim indigo')],
#  'bright gray': [(5, 'pale yellow')],
#  'plaid salmon': [(3, 'shiny indigo')],
#  'dotted bronze': [(5, 'mirrored black'),
#   (3, 'muted indigo'),
#   (3, 'faded yellow'),
#   (3, 'bright teal')],
#  'mirrored crimson': [(2, 'pale salmon'), (1, 'plaid maroon')],
#  'wavy brown': [(1, 'drab turquoise'), (3, 'posh yellow')],
#  'muted coral': [(4, 'clear blue'), (5, 'dark cyan')],
#  'wavy yellow': [(2, 'drab brown'), (2, 'striped olive'), (1, 'wavy white')],
#  'muted aqua': [(2, 'light tan'), (2, 'pale yellow'), (5, 'plaid lime')],
#  'drab crimson': [(5, 'plaid cyan'), (3, 'dim plum')],
#  'vibrant yellow': [(2, 'faded maroon'),
#   (4, 'mirrored olive'),
#   (2, 'plaid red')],
#  'faded silver': [(4, 'dim lime'),
#   (4, 'dark tomato'),
#   (5, 'muted magenta'),
#   (1, 'dotted red')],
#  'drab violet': [(2, 'vibrant aqua')],
#  'faded teal': [(2, 'light gold'),
#   (5, 'striped turquoise'),
#   (2, 'dim salmon'),
#   (2, 'posh tomato')],
#  'wavy magenta': [(4, 'faded blue'), (1, 'muted brown'), (3, 'pale brown')],
#  'vibrant salmon': [(2, 'posh turquoise'), (1, 'dark crimson')],
#  'bright olive': [(4, 'light teal'),
#   (2, 'vibrant lime'),
#   (3, 'dull salmon'),
#   (2, 'dull tomato')],
#  'plaid teal': [(5, 'striped teal')],
#  'dark cyan': [(3, 'dull brown'), (4, 'posh violet')],
#  'muted olive': [(1, 'faded blue'), (5, 'dotted brown')],
#  'dark violet': [(3, 'mirrored beige')],
#  'drab orange': [(4, 'faded aqua'),
#   (1, 'striped red'),
#   (5, 'mirrored maroon')],
#  'wavy gray': [(4, 'mirrored green')],
#  'faded white': [(3, 'dim lavender'), (3, 'clear silver')],
#  'faded lavender': [(2, 'posh violet'),
#   (4, 'striped violet'),
#   (2, 'clear silver'),
#   (2, 'faded cyan')],
#  'light red': [(2, 'bright white'), (1, 'dull gray'), (3, 'bright lavender')],
#  'bright beige': [(3, 'mirrored silver')],
#  'shiny magenta': [(1, 'light silver')],
#  'striped teal': [(1, 'plaid lime'),
#   (2, 'clear tomato'),
#   (1, 'clear chartreuse')],
#  'dim olive': [(5, 'pale white'),
#   (5, 'wavy black'),
#   (4, 'faded magenta'),
#   (4, 'dark red')],
#  'dull tan': [(3, 'dark lavender'), (5, 'faded violet')],
#  'striped purple': [(5, 'wavy violet'), (5, 'light gold')],
#  'dim crimson': [(5, 'striped magenta')],
#  'faded beige': [(2, 'striped brown'), (3, 'dark salmon')],
#  'light purple': [(2, 'bright lavender'),
#   (5, 'vibrant lime'),
#   (3, 'striped blue')],
#  'mirrored blue': [(2, 'clear white'), (2, 'drab cyan'), (5, 'light cyan')],
#  'dull silver': [(1, 'shiny bronze'), (1, 'dotted beige')],
#  'pale crimson': [(2, 'shiny turquoise')],
#  'wavy indigo': [(5, 'clear white'),
#   (5, 'plaid cyan'),
#   (1, 'muted brown'),
#   (1, 'pale yellow')],
#  'bright chartreuse': [(3, 'posh crimson'), (5, 'shiny maroon')],
#  'vibrant silver': [(3, 'striped aqua'),
#   (5, 'striped gold'),
#   (2, 'dim lime'),
#   (4, 'clear chartreuse')],
#  'dark purple': [(4, 'plaid lavender'),
#   (3, 'clear chartreuse'),
#   (4, 'striped teal')],
#  'vibrant turquoise': [(1, 'light gold'),
#   (1, 'light turquoise'),
#   (4, 'muted indigo'),
#   (2, 'wavy magenta')],
#  'vibrant tan': [(1, 'dull purple'), (5, 'vibrant beige')],
#  'dim salmon': [(1, 'striped violet'),
#   (5, 'light teal'),
#   (5, 'light tan'),
#   (5, 'striped brown')],
#  'muted violet': [(5, 'bright brown'),
#   (5, 'faded aqua'),
#   (3, 'clear purple'),
#   (4, 'plaid lavender')],
#  'mirrored gray': [(4, 'drab maroon'), (3, 'posh violet')],
#  'striped blue': [(2, 'plaid cyan'), (5, 'pale gold')],
#  'vibrant gray': [(4, 'pale magenta'),
#   (4, 'vibrant bronze'),
#   (3, 'drab silver'),
#   (4, 'posh tomato')],
#  'faded tan': [(4, 'plaid olive')],
#  'muted green': [(2, 'posh cyan'), (1, 'plaid lime'), (5, 'muted crimson')],
#  'shiny tomato': [(3, 'wavy violet'), (4, 'posh coral'), (3, 'striped red')],
#  'muted plum': [(2, 'plaid salmon')],
#  'pale indigo': [(3, 'pale cyan'), (5, 'vibrant lime'), (5, 'vibrant tomato')],
#  'mirrored fuchsia': [(4, 'posh gray'), (3, 'muted tan'), (4, 'dim blue')],
#  'dark lime': [(3, 'clear black'), (3, 'dark tomato'), (2, 'mirrored black')],
#  'muted white': [(3, 'shiny black'),
#   (5, 'dark purple'),
#   (3, 'vibrant silver')],
#  'striped gray': [(5, 'dark salmon')],
#  'dotted fuchsia': [(1, 'mirrored red'), (3, 'dotted lavender')],
#  'posh maroon': [(1, 'mirrored beige')],
#  'vibrant plum': [(3, 'clear red')],
#  'posh turquoise': [(2, 'shiny magenta')],
#  'light black': [(4, 'light orange'), (1, 'dark salmon'), (4, 'striped plum')],
#  'clear yellow': [(1, 'posh aqua')],
#  'dim purple': [(2, 'striped green')],
#  'muted tan': [(4, 'mirrored gray'), (1, 'dotted violet')],
#  'drab silver': [(5, 'clear chartreuse'),
#   (1, 'drab olive'),
#   (2, 'posh coral'),
#   (5, 'bright lime')],
#  'plaid bronze': [(3, 'wavy black'),
#   (4, 'wavy orange'),
#   (3, 'dim tomato'),
#   (3, 'muted teal')],
#  'dark green': [(5, 'dull red'),
#   (3, 'bright crimson'),
#   (5, 'shiny salmon'),
#   (1, 'muted purple')],
#  'bright silver': [(1, 'striped cyan')],
#  'striped lime': [(2, 'dim magenta'),
#   (5, 'faded chartreuse'),
#   (2, 'clear indigo')],
#  'dotted gold': [(2, 'light cyan')],
#  'drab black': [(5, 'faded red'), (5, 'plaid orange')],
#  'dim magenta': [(5, 'dull coral')],
#  'light plum': [(4, 'light yellow'),
#   (5, 'shiny bronze'),
#   (5, 'posh purple'),
#   (5, 'plaid olive')],
#  'dotted cyan': [(5, 'light salmon'), (4, 'dull tomato'), (3, 'clear blue')],
#  'posh blue': [(4, 'muted brown'), (2, 'muted aqua')],
#  'posh gray': [(4, 'pale green'), (2, 'faded chartreuse'), (2, 'drab blue')],
#  'clear tan': [(4, 'clear gray')],
#  'mirrored salmon': [(1, 'dull tan'),
#   (4, 'mirrored plum'),
#   (5, 'muted tan'),
#   (3, 'plaid blue')],
#  'light brown': [(1, 'dim chartreuse')],
#  'dull lavender': [(1, 'drab white'), (5, 'dull indigo')],
#  'striped violet': [(5, 'muted brown'), (3, 'plaid cyan'), (2, 'light gray')],
#  'clear crimson': [(1, 'drab teal'),
#   (5, 'dark tan'),
#   (1, 'pale salmon'),
#   (4, 'dull turquoise')],
#  'dim white': [(3, 'bright olive')],
#  'dim green': [(4, 'light silver'), (1, 'wavy green'), (1, 'striped gold')],
#  'dull maroon': [(4, 'wavy magenta')],
#  'striped lavender': [(5, 'faded white'),
#   (4, 'mirrored tomato'),
#   (5, 'mirrored crimson')],
#  'faded tomato': [(4, 'pale gray')],
#  'pale cyan': [(1, 'dull beige'), (4, 'light white'), (5, 'clear tan')],
#  'wavy tomato': [(5, 'dotted silver'), (5, 'faded gray'), (1, 'striped teal')],
#  'dim tomato': [(4, 'bright lime'),
#   (3, 'dim lavender'),
#   (3, 'muted tomato'),
#   (4, 'dark crimson')],
#  'striped tomato': [(3, 'plaid chartreuse'), (4, 'light cyan')],
#  'plaid gold': [(1, 'dark yellow')],
#  'dark silver': [(2, 'dull blue'), (2, 'bright purple'), (5, 'dim tomato')],
#  'dotted purple': [(4, 'striped blue')],
#  'dark fuchsia': [(2, 'light cyan')],
#  'dotted salmon': [(3, 'drab teal'), (5, 'dotted teal'), (4, 'vibrant white')],
#  'mirrored gold': [(2, 'striped salmon'),
#   (5, 'pale fuchsia'),
#   (3, 'dull purple')],
#  'posh violet': [(1, 'dim salmon'), (5, 'clear gold'), (1, 'bright salmon')],
#  'shiny beige': [(2, 'muted brown'), (4, 'shiny gold'), (5, 'wavy indigo')],
#  'plaid cyan': [(5, 'muted tomato'),
#   (4, 'drab gray'),
#   (2, 'dark crimson'),
#   (1, 'striped brown')],
#  'vibrant lime': [(5, 'dull magenta')],
#  'clear black': [(3, 'wavy lavender')],
#  'light coral': [(2, 'pale salmon'),
#   (1, 'striped brown'),
#   (5, 'mirrored plum'),
#   (1, 'drab gold')],
#  'faded aqua': [(2, 'pale blue'), (4, 'drab lavender')],
#  'wavy gold': [(1, 'dotted plum')],
#  'shiny turquoise': [(4, 'dull gray'), (2, 'dim orange')],
#  'dull purple': [(1, 'shiny gold'), (3, 'plaid olive')],
#  'dull coral': [(1, 'faded tan'),
#   (4, 'clear chartreuse'),
#   (3, 'shiny crimson'),
#   (4, 'plaid lavender')],
#  'dull red': [(5, 'dotted beige'), (4, 'striped tomato'), (1, 'shiny yellow')],
#  'bright bronze': [(2, 'wavy black'), (5, 'mirrored bronze')],
#  'faded violet': [(3, 'pale yellow'),
#   (5, 'posh cyan'),
#   (5, 'wavy purple'),
#   (5, 'vibrant magenta')],
#  'shiny blue': [(1, 'dotted teal'),
#   (4, 'wavy purple'),
#   (2, 'striped brown'),
#   (3, 'bright lavender')],
#  'striped salmon': [(2, 'light tan'),
#   (4, 'striped red'),
#   (1, 'striped indigo'),
#   (1, 'pale gold')],
#  'shiny silver': [(4, 'faded silver'), (4, 'clear maroon')],
#  'faded crimson': [(1, 'faded bronze'),
#   (5, 'dull brown'),
#   (5, 'posh plum'),
#   (3, 'shiny plum')],
#  'vibrant tomato': [(3, 'plaid cyan'),
#   (5, 'drab teal'),
#   (5, 'dotted crimson'),
#   (5, 'light tan')],
#  'plaid red': [(2, 'vibrant gray'),
#   (5, 'shiny bronze'),
#   (5, 'dull black'),
#   (2, 'light yellow')],
#  'muted red': [(2, 'clear indigo'),
#   (4, 'dotted lime'),
#   (3, 'dim gray'),
#   (1, 'mirrored lime')],
#  'mirrored chartreuse': [(2, 'dull black'), (1, 'dark white')],
#  'dim gold': [(3, 'plaid blue'), (2, 'dotted purple')],
#  'pale white': [(3, 'pale yellow'),
#   (1, 'bright tan'),
#   (4, 'striped orange'),
#   (4, 'light yellow')],
#  'light magenta': [(3, 'light black'), (4, 'muted turquoise')],
#  'shiny lime': [(1, 'drab cyan')],
#  'light teal': [(3, 'dim plum'), (1, 'posh black'), (3, 'dull beige')],
#  'plaid black': [(4, 'faded silver'), (2, 'faded magenta')],
#  'clear orange': [(1, 'posh orange'),
#   (4, 'bright orange'),
#   (5, 'clear indigo')],
#  'clear coral': [(3, 'faded crimson'), (1, 'dull silver')],
#  'muted lime': [(2, 'dim plum')],
#  'shiny purple': [(5, 'faded aqua')],
#  'vibrant gold': [(5, 'drab lavender'), (4, 'striped red')],
#  'clear white': [],
#  'posh aqua': [(2, 'light blue'),
#   (1, 'posh turquoise'),
#   (4, 'faded teal'),
#   (3, 'dotted purple')],
#  'posh black': [],
#  'mirrored maroon': [(4, 'plaid blue'),
#   (3, 'dotted maroon'),
#   (5, 'striped plum')],
#  'dotted crimson': [(5, 'striped salmon'),
#   (1, 'pale brown'),
#   (1, 'posh black'),
#   (5, 'bright lime')],
#  'striped orange': [(4, 'faded olive')],
#  'posh teal': [(2, 'faded lavender'), (3, 'dim indigo')],
#  'striped bronze': [(2, 'bright lavender'),
#   (2, 'plaid olive'),
#   (3, 'vibrant brown'),
#   (5, 'pale maroon')],
#  'dull orange': [(3, 'dark crimson'),
#   (5, 'pale salmon'),
#   (4, 'vibrant gray'),
#   (4, 'plaid olive')],
#  'clear maroon': [(2, 'wavy gray'), (2, 'clear blue')],
#  'clear tomato': [(1, 'drab olive'), (2, 'muted brown')],
#  'dark aqua': [(3, 'striped white')],
#  'dull chartreuse': [(3, 'faded tan'),
#   (3, 'light orange'),
#   (2, 'clear chartreuse')],
#  'dim cyan': [(1, 'shiny green'),
#   (4, 'vibrant brown'),
#   (4, 'faded yellow'),
#   (1, 'striped aqua')],
#  'pale orange': [(3, 'drab indigo'), (4, 'plaid green'), (2, 'wavy lavender')],
#  'dull cyan': [(5, 'mirrored turquoise'),
#   (3, 'posh indigo'),
#   (5, 'drab tomato'),
#   (3, 'bright aqua')],
#  'drab brown': [(2, 'clear tan'),
#   (1, 'faded yellow'),
#   (4, 'vibrant coral'),
#   (3, 'mirrored blue')],
#  'plaid blue': [(1, 'light teal'), (1, 'faded tan')],
#  'dotted orange': [(5, 'dull fuchsia'), (3, 'muted brown')],
#  'muted salmon': [(2, 'wavy coral')],
#  'pale brown': [(4, 'light tan'),
#   (3, 'dim coral'),
#   (2, 'plaid olive'),
#   (4, 'striped brown')],
#  'wavy tan': [(4, 'mirrored blue'), (1, 'posh purple')],
#  'mirrored plum': [(4, 'plaid tan'),
#   (3, 'wavy yellow'),
#   (4, 'vibrant magenta'),
#   (3, 'pale lavender')],
#  'bright purple': [(4, 'dark red'), (5, 'clear white')],
#  'shiny chartreuse': [(4, 'posh plum')],
#  'shiny violet': [(4, 'mirrored indigo'), (1, 'faded beige')],
#  'drab maroon': [(5, 'posh cyan')],
#  'dim lavender': [(2, 'vibrant magenta'),
#   (4, 'posh black'),
#   (5, 'bright lime'),
#   (3, 'light tan')],
#  'shiny gold': [(2, 'muted fuchsia'), (3, 'clear silver')],
#  'wavy violet': [(2, 'vibrant magenta'),
#   (5, 'striped red'),
#   (4, 'plaid lime'),
#   (2, 'bright lime')],
#  'light beige': [(3, 'pale tan')],
#  'dotted lavender': [(5, 'dim plum'), (1, 'dull magenta')],
#  'clear teal': [(2, 'plaid yellow'),
#   (4, 'light blue'),
#   (4, 'striped maroon'),
#   (1, 'vibrant olive')],
#  'faded purple': [(2, 'clear olive'), (4, 'mirrored teal'), (2, 'plaid gold')],
#  'pale lime': [(5, 'drab yellow'), (4, 'bright coral')],
#  'plaid beige': [(2, 'faded violet'), (5, 'plaid tan')],
#  'wavy lavender': [(5, 'striped brown')],
#  'dull tomato': [(4, 'faded olive')],
#  'plaid plum': [(4, 'faded cyan'), (2, 'clear olive')],
#  'dark gray': [(2, 'dark red'), (3, 'clear indigo'), (5, 'dim tomato')],
#  'plaid lavender': [(5, 'plaid green'), (1, 'shiny tomato')],
#  'dim aqua': [(5, 'clear silver')],
#  'dark salmon': [(1, 'drab olive'), (5, 'posh coral')],
#  'vibrant violet': [(3, 'dim plum'),
#   (3, 'dim turquoise'),
#   (3, 'striped orange')],
#  'mirrored red': [(3, 'dull gray'),
#   (5, 'mirrored violet'),
#   (3, 'vibrant coral')],
#  'mirrored brown': [(3, 'vibrant tomato'), (1, 'wavy lavender')],
#  'mirrored bronze': [(1, 'striped orange'), (1, 'drab gray')],
#  'dotted lime': [(5, 'drab cyan'),
#   (3, 'dotted maroon'),
#   (2, 'vibrant white'),
#   (5, 'plaid crimson')],
#  'dotted chartreuse': [(5, 'bright maroon')],
#  'clear violet': [(5, 'striped orange'),
#   (2, 'muted lime'),
#   (4, 'vibrant bronze'),
#   (2, 'drab silver')],
#  'plaid magenta': [(2, 'bright blue'), (2, 'shiny chartreuse')],
#  'mirrored orange': [(1, 'striped yellow'),
#   (1, 'drab gold'),
#   (5, 'striped beige'),
#   (4, 'pale brown')],
#  'drab salmon': [(5, 'clear yellow'), (1, 'dark beige')],
#  'drab magenta': [(4, 'dull gray'), (4, 'faded tan')],
#  'dim maroon': [(4, 'striped teal'),
#   (5, 'striped black'),
#   (2, 'drab indigo'),
#   (4, 'vibrant beige')],
#  'wavy olive': [(5, 'faded chartreuse'),
#   (2, 'dotted lavender'),
#   (3, 'wavy brown'),
#   (3, 'dim turquoise')],
#  'light aqua': [(3, 'dark violet'), (3, 'posh tomato')],
#  'dark chartreuse': [(3, 'light plum'),
#   (4, 'vibrant chartreuse'),
#   (3, 'dotted purple'),
#   (1, 'light turquoise')],
#  'shiny red': [(4, 'dotted maroon'), (3, 'dull coral'), (3, 'dim coral')],
#  'dark gold': [(3, 'dim chartreuse')],
#  'dark turquoise': [(4, 'dark olive')],
#  'plaid yellow': [(1, 'dark salmon'),
#   (3, 'drab olive'),
#   (4, 'posh fuchsia'),
#   (3, 'mirrored teal')],
#  'muted tomato': [(1, 'vibrant magenta'), (2, 'light cyan')],
#  'dark brown': [(4, 'muted magenta'),
#   (3, 'light turquoise'),
#   (5, 'dim silver')],
#  'dark bronze': [(2, 'striped red'), (4, 'vibrant coral')],
#  'posh fuchsia': [(2, 'faded tan')],
#  'dark teal': [(5, 'dark salmon'),
#   (1, 'faded violet'),
#   (2, 'drab olive'),
#   (4, 'dim plum')],
#  'drab yellow': [(4, 'plaid tan'), (1, 'dull white'), (3, 'dull violet')],
#  'dotted gray': [(2, 'vibrant lavender'),
#   (1, 'striped aqua'),
#   (5, 'drab violet'),
#   (1, 'light red')],
#  'drab purple': [(5, 'posh orange')],
#  'striped crimson': [(3, 'striped salmon'),
#   (1, 'posh plum'),
#   (1, 'pale orange'),
#   (5, 'posh indigo')],
#  'muted orange': [(4, 'muted silver'), (4, 'dotted plum'), (5, 'shiny blue')],
#  'muted gray': [(2, 'muted salmon'),
#   (3, 'bright bronze'),
#   (5, 'bright brown')],
#  'dull turquoise': [(2, 'plaid olive'),
#   (5, 'striped turquoise'),
#   (5, 'muted brown'),
#   (1, 'vibrant magenta')],
#  'dotted maroon': [(2, 'dim salmon'), (5, 'clear white'), (4, 'wavy black')],
#  'striped coral': [(2, 'shiny violet'),
#   (5, 'plaid maroon'),
#   (3, 'bright tan'),
#   (4, 'mirrored chartreuse')],
#  'dark tan': [(4, 'faded white')],
#  'posh plum': [(5, 'pale brown'),
#   (3, 'muted brown'),
#   (4, 'posh cyan'),
#   (1, 'light turquoise')],
#  'shiny plum': [(4, 'dull turquoise'), (1, 'shiny gold')],
#  'posh indigo': [(1, 'bright brown'), (2, 'dull silver')],
#  'muted fuchsia': [(5, 'plaid olive')],
#  'drab bronze': [(3, 'drab coral'),
#   (3, 'dull chartreuse'),
#   (2, 'posh turquoise')],
#  'shiny white': [(5, 'dark tan'), (5, 'shiny magenta')],
#  'mirrored green': [(5, 'light maroon'), (1, 'light gold')],
#  'mirrored aqua': [(1, 'striped chartreuse'),
#   (4, 'faded coral'),
#   (1, 'muted silver')],
#  'vibrant orange': [(3, 'plaid tan')],
#  'shiny black': [(1, 'mirrored gray'),
#   (1, 'posh fuchsia'),
#   (3, 'muted salmon'),
#   (4, 'dotted crimson')],
#  'dark blue': [(1, 'shiny tomato'), (5, 'posh beige')],
#  'bright crimson': [(1, 'striped green')],
#  'posh chartreuse': [(3, 'dim magenta'), (2, 'dull orange')],
#  'pale gray': [(1, 'drab coral')],
#  'muted gold': [(1, 'muted orange'),
#   (5, 'faded beige'),
#   (1, 'wavy tomato'),
#   (5, 'posh lime')],
#  'faded red': [(3, 'dark bronze')],
#  'striped maroon': [(1, 'dark salmon'), (4, 'dim coral'), (1, 'posh coral')],
#  'muted magenta': [(4, 'muted teal'),
#   (5, 'dotted turquoise'),
#   (3, 'pale plum'),
#   (4, 'faded bronze')],
#  'vibrant aqua': [(4, 'faded crimson')],
#  'bright teal': [(4, 'bright olive'),
#   (5, 'mirrored black'),
#   (4, 'drab coral'),
#   (3, 'dotted beige')],
#  'dim orange': [(2, 'shiny fuchsia'), (3, 'striped magenta')],
#  'dotted white': [(5, 'mirrored blue'),
#   (3, 'shiny tomato'),
#   (1, 'dull coral')],
#  'clear magenta': [(3, 'dark teal'), (3, 'vibrant white')],
#  'light fuchsia': [(5, 'light violet'), (2, 'striped aqua')]}

# %%
def build_parent_dict(bag_info):
    parent_dict = defaultdict(list)
    
    for base_color, children in bag_info.items():
        for num, child_color in children:
            parent_dict[child_color].append(base_color)
            
    return parent_dict

# %%
parent_dict = build_parent_dict(bag_info)

# %%
parent_dict['muted salmon']
# Out:
# ['vibrant black', 'muted gray', 'shiny black']

# %%
parent_dict['dotted gold']
# Out:
# ['drab plum', 'dull teal']

# %%
parent_dict['shiny gold']
# Out:
# ['mirrored purple',
#  'light chartreuse',
#  'vibrant olive',
#  'shiny beige',
#  'dull purple',
#  'shiny plum']

# %%
test_bag_info = get_bag_info(test_instructions)

# %%
test_parent_dict = build_parent_dict(test_bag_info)

# %%
def nodes_to_root(parent_dict, color, memo=dict()):
    if color in memo:
        return memo[color]
    
    parents = parent_dict[color]
    
    answer = set(parents) | set.union(*(nodes_to_root(parent_dict, parent_color, memo) for parent_color in parents), set())
    memo[color] = answer
    
    return answer

# %%
nodes_to_root(test_parent_dict, 'shiny gold')
# Out:
# {'bright white', 'dark orange', 'light red', 'muted yellow'}

# %%
s = nodes_to_root(parent_dict, 'shiny gold', memo=dict())

# %%
len(s)
# Out:
# 151

# %% [markdown]
# Part Two

# %%
test_input = '''shiny gold bags contain 2 dark red bags.
dark red bags contain 2 dark orange bags.
dark orange bags contain 2 dark yellow bags.
dark yellow bags contain 2 dark green bags.
dark green bags contain 2 dark blue bags.
dark blue bags contain 2 dark violet bags.
dark violet bags contain no other bags.'''

test_instructions = test_input.split('\n')

# %%
test_bag_info = get_bag_info(test_instructions)

# %%
test_bag_info
# Out:
# {'shiny gold': [(2, 'dark red')],
#  'dark red': [(2, 'dark orange')],
#  'dark orange': [(2, 'dark yellow')],
#  'dark yellow': [(2, 'dark green')],
#  'dark green': [(2, 'dark blue')],
#  'dark blue': [(2, 'dark violet')],
#  'dark violet': []}

# %%
def num_bags_inside(bag_info, color, memo=dict()):    
    children = bag_info[color]
    
    if not children:
        return 0
    elif color in memo:
        return memo[color]
    else:
        s = sum(num * (num_bags_inside(bag_info, child_color, memo) + 1) for num, child_color in children)
        memo[color] = s
        return s

# %%
num_bags_inside(test_bag_info, 'shiny gold')
# Out:
# 126

# %%
num_bags_inside(bag_info, 'shiny gold', memo=dict())
# Out:
# 41559
