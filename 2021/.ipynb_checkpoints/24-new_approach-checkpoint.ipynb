# %%
import itertools
import numpy as np
import random
from copy import deepcopy

# %%
puzzle_input = open('inputs/24').read().strip()

# %%
ex_model_num = 13579246899999
ex_model_num = 93539246899999
model_digits = [int(i) for i in ' '.join(str(ex_model_num)).split(' ')]

# %%
model_digits
# Out:
# [9, 3, 5, 3, 9, 2, 4, 6, 8, 9, 9, 9, 9, 9]

# %%
puzzle_input.splitlines()[:20]
# Out:
# ['inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 1',
#  'add x 12',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 7',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0']

# %%
len(puzzle_input.splitlines())
# Out:
# 252

# %%
op_lookup = {
    'add': lambda x, y: x + y,
    'mul': lambda x, y: x * y,
    # 'div': lambda x, y: x // y,
    'div': lambda x, y: int(x / y),
    'mod': lambda x, y: x % y,
    'eql': lambda x, y: int(x == y),
}

# %%
op_str_lookup = {
    'add': "+",
    'mul': "*",
    'div': "//",
    'mod': "%",
    'eql': "=="
}

# %%
from dataclasses import dataclass

class Expression:
    ...

@dataclass
class MyInt(Expression):
    n: int
        
    def __repr__(self):
        return str(self.n)
    
    def __eq__(self, other):
        return type(self) == type(other) and self.n == other.n
    
@dataclass    
class Variable(Expression):
    name: str
        
    def __repr__(self):
        return self.name
    
    def __eq__(self, other):
        return type(self) == type(other) and self.__repr__() == other.__repr__()

@dataclass
class Digit(Expression):
    digit_num: int
        
    def __repr__(self):
        return f'd{self.digit_num}'
    
    def __eq__(self, other):
        return type(self) == type(other) and self.digit_num == other.digit_num

@dataclass
class Opr(Expression):
    opr: str
    left: Expression
    right: Expression
        
    def __repr__(self):
        return f"({self.left.__repr__()} {op_str_lookup[self.opr]} {self.right.__repr__()})"
    
    def __eq__(self, other):
        return type(self) == type(other) and self.opr == other.opr and self.left == other.left and self.right == other.right

# %%
def reduce(op: Opr) -> Expression:    
    match op:
        case Opr(op_name, MyInt(x), MyInt(y)):
            return MyInt(op_lookup[op_name](x, y))

        case Opr('add', MyInt(0), y):
            return y
        
        case Opr('add', x, MyInt(0)):
            return x
        
        # (d3 + 2) + 12)
        case Opr('add', Opr('add', e, MyInt(j)), MyInt(k)):
            return Opr('add', e, MyInt(j+k))
        
        # ???????
        # ((d1 * 26) + 182) + (d2 + 8)
        # => (d1*26) + d2 + 190
        case Opr('add', Opr('add', a, MyInt(b)), Opr('add', c, MyInt(d))):
            # is this extra reduction necessary here? hmm
            return Opr('add', reduce(Opr('add', a, c)), MyInt(b+d))

        case Opr('mul', x, MyInt(1)):
            return x
        case Opr('mul', MyInt(1), y):
            return y
        case Opr('mul', x, MyInt(0)):
            return MyInt(0)
        case Opr('mul', MyInt(0), y):
            return MyInt(0)

        # distributive
        # case Opr('mul', Opr('add', a, b), c):
        #      return reduce(Opr('add', reduce(Opr('mul', a, c)), reduce(Opr('mul', b, c))))
        
        # (d1*2)*2 = d1 * 2 
        case Opr('mul', Opr('mul', Digit(d), MyInt(x)), MyInt(y)):
            return Opr('mul', Digit(d), MyInt(x*y))

        case Opr('div', x, MyInt(1)):
            return x
        
        # ((((((((d1 + 7) * 26) + (d2 + 8)) * 26) + (d3 + 2)) * 26) + (d4 + 11)) // 26)
        # check to see if the thing on left is multiple of 26
        case Opr("div", Opr('add', Opr('mul', a, MyInt(j)), b), MyInt(k)):
            print('whacked out case div')
            if j == k:
                return reduce(Opr("add", a, reduce(Opr('div', b, MyInt(j)))))
            
            return op
        
        # ((d4 + 11) // 26)
        case Opr("div", Opr("add", Digit(d), MyInt(k)), MyInt(n)):
            if 10 + k < 26:
                return MyInt(0)
            
            return op
        
        case Opr('mod', MyInt(0), y):
            return MyInt(0)

        case Opr('mod', Digit(d), MyInt(y)):
            if y >= 10:
                return Digit(d)

            return op
        
        # (a + b) % n = (a % n + b % n) % n
        # actually.. this will cause infinite recursion. need something more specific
        # case Opr('mod', Opr('add', a, b), n):
        #    return reduce(Opr('mod', reduce(Opr('add', reduce(Opr('mod', a, n)), reduce(Opr('mod', b, n)))), n))
        
        
        # (((d1 + 7) * 26) + (d2 + 8)) % 26
        
        case Opr("mod", Opr('add', Opr('mul', a, MyInt(j)), b), MyInt(k)):
            print('whacked out case mod')
            if j == k:
                return reduce(Opr('mod', b, MyInt(k)))
            
            return op
        
        
        # (a % n) % n = a % n
        case Opr('mod', Opr('mod', a, n), k):
            print('mod collapse')
            if n == k:
                # need recursion?
                return Opr('mod', a, n)
            
            return op
        
        # (d1 * 17576) % 26)
        case Opr('mod', Opr('mul', e, MyInt(x)), MyInt(n)):
            print("new case")
            if x >= n:
                # reduces necessary?
                return reduce(Opr('mod', reduce(Opr('mul', e, MyInt(x % n))), MyInt(n)))
            
            return op
        
        
        case Opr('mod', Opr('mul', a, b), e):
            print('reducing mod to 0')
            if b == e:
                return MyInt(0)
            
            return op
        

        # (d4 + 11) % 26
        # 9 + j
        case Opr('mod', Opr('add', Digit(d), MyInt(j)), MyInt(k)):
            if 9 + j < k:
                return Opr('add', Digit(d), MyInt(j))
            
            return op

        case Opr('eql', Digit(d), MyInt(y)):
            if y <= 0 or y >= 10:
                return MyInt(0)

            return op

        case Opr('eql', MyInt(x), Digit(d)):
            if x <= 0 or x >= 10:
                return MyInt(0)
            
            return op

        # ((a % b) + 20) == d1
        case Opr('eql', Opr('add', Opr('mod', a, b), MyInt(x)), Digit(d)):
            print('mod plus too large equals digit')
            if x >= 10:
                return MyInt(0)

            return op
        
        
        # (d1 + 20) == d2
        # smallest valid configuration is
        # (d1 + 8) == d2 where d1=1 and d2=9
        case Opr('eql', Opr('add', Digit(d1), MyInt(x)), Digit(d2)):
            if x > 8:
                return MyInt(0)

            return op

        case _:
            return op

# %%
ins = puzzle_input.splitlines()

# %%
ins[-20:]
# Out:
# ['mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 26',
#  'add x -11',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 5',
#  'mul y x',
#  'add z y']

# %%
instruction_blocks = [lst.splitlines()[1:] for lst in puzzle_input.split('inp w')[1:]]

# %%
len(instruction_blocks)
# Out:
# 14

# %%
final_expressions = []

for block_num, instruction_block in enumerate(instruction_blocks):
    print(f'--Block num {block_num}--')
    
    if block_num == 0:
        expressions = {
            'x': MyInt(0),
            'y': MyInt(0),
            'z': MyInt(0),
            'w': Digit(block_num+1)
        }
    else:
        expressions = {
            'x': Variable(f'x{block_num}'),
            'y': Variable(f'y{block_num}'),
            'z': Variable(f'z{block_num}'),
            'w': Digit(block_num+1)
        }

    for i, instruction in enumerate(instruction_block):
        instr, *rest = instruction.split()

        var, other = rest

        left = expressions[var]
        right = expressions[other] if other in expressions else MyInt(int(other))        

        op = Opr(instr, left, right)

        result = reduce(op)

        expressions[var] = result
        print(i)
        print(instruction)
        print(expressions)
        
    print()
    print()
    
    final_expressions.append(expressions)
# Out:
# --Block num 0--
# 0
# mul x 0
# {'x': 0, 'y': 0, 'z': 0, 'w': d1}
# 1
# add x z
# {'x': 0, 'y': 0, 'z': 0, 'w': d1}
# 2
# mod x 26
# {'x': 0, 'y': 0, 'z': 0, 'w': d1}
# 3
# div z 1
# {'x': 0, 'y': 0, 'z': 0, 'w': d1}
# 4
# add x 12
# {'x': 12, 'y': 0, 'z': 0, 'w': d1}
# 5
# eql x w
# {'x': 0, 'y': 0, 'z': 0, 'w': d1}
# 6
# eql x 0
# {'x': 1, 'y': 0, 'z': 0, 'w': d1}
# 7
# mul y 0
# {'x': 1, 'y': 0, 'z': 0, 'w': d1}
# 8
# add y 25
# {'x': 1, 'y': 25, 'z': 0, 'w': d1}
# 9
# mul y x
# {'x': 1, 'y': 25, 'z': 0, 'w': d1}
# 10
# add y 1
# {'x': 1, 'y': 26, 'z': 0, 'w': d1}
# 11
# mul z y
# {'x': 1, 'y': 26, 'z': 0, 'w': d1}
# 12
# mul y 0
# {'x': 1, 'y': 0, 'z': 0, 'w': d1}
# 13
# add y w
# {'x': 1, 'y': d1, 'z': 0, 'w': d1}
# 14
# add y 7
# {'x': 1, 'y': (d1 + 7), 'z': 0, 'w': d1}
# 15
# mul y x
# {'x': 1, 'y': (d1 + 7), 'z': 0, 'w': d1}
# 16
# add z y
# {'x': 1, 'y': (d1 + 7), 'z': (d1 + 7), 'w': d1}
#
#
# --Block num 1--
# 0
# mul x 0
# {'x': 0, 'y': y1, 'z': z1, 'w': d2}
# 1
# add x z
# {'x': z1, 'y': y1, 'z': z1, 'w': d2}
# 2
# mod x 26
# {'x': (z1 % 26), 'y': y1, 'z': z1, 'w': d2}
# 3
# div z 1
# {'x': (z1 % 26), 'y': y1, 'z': z1, 'w': d2}
# 4
# add x 12
# {'x': ((z1 % 26) + 12), 'y': y1, 'z': z1, 'w': d2}
# mod plus too large equals digit
# 5
# eql x w
# {'x': 0, 'y': y1, 'z': z1, 'w': d2}
# 6
# eql x 0
# {'x': 1, 'y': y1, 'z': z1, 'w': d2}
# 7
# mul y 0
# {'x': 1, 'y': 0, 'z': z1, 'w': d2}
# 8
# add y 25
# {'x': 1, 'y': 25, 'z': z1, 'w': d2}
# 9
# mul y x
# {'x': 1, 'y': 25, 'z': z1, 'w': d2}
# 10
# add y 1
# {'x': 1, 'y': 26, 'z': z1, 'w': d2}
# 11
# mul z y
# {'x': 1, 'y': 26, 'z': (z1 * 26), 'w': d2}
# 12
# mul y 0
# {'x': 1, 'y': 0, 'z': (z1 * 26), 'w': d2}
# 13
# add y w
# {'x': 1, 'y': d2, 'z': (z1 * 26), 'w': d2}
# 14
# add y 8
# {'x': 1, 'y': (d2 + 8), 'z': (z1 * 26), 'w': d2}
# 15
# mul y x
# {'x': 1, 'y': (d2 + 8), 'z': (z1 * 26), 'w': d2}
# 16
# add z y
# {'x': 1, 'y': (d2 + 8), 'z': ((z1 * 26) + (d2 + 8)), 'w': d2}
#
#
# --Block num 2--
# 0
# mul x 0
# {'x': 0, 'y': y2, 'z': z2, 'w': d3}
# 1
# add x z
# {'x': z2, 'y': y2, 'z': z2, 'w': d3}
# 2
# mod x 26
# {'x': (z2 % 26), 'y': y2, 'z': z2, 'w': d3}
# 3
# div z 1
# {'x': (z2 % 26), 'y': y2, 'z': z2, 'w': d3}
# 4
# add x 13
# {'x': ((z2 % 26) + 13), 'y': y2, 'z': z2, 'w': d3}
# mod plus too large equals digit
# 5
# eql x w
# {'x': 0, 'y': y2, 'z': z2, 'w': d3}
# 6
# eql x 0
# {'x': 1, 'y': y2, 'z': z2, 'w': d3}
# 7
# mul y 0
# {'x': 1, 'y': 0, 'z': z2, 'w': d3}
# 8
# add y 25
# {'x': 1, 'y': 25, 'z': z2, 'w': d3}
# 9
# mul y x
# {'x': 1, 'y': 25, 'z': z2, 'w': d3}
# 10
# add y 1
# {'x': 1, 'y': 26, 'z': z2, 'w': d3}
# 11
# mul z y
# {'x': 1, 'y': 26, 'z': (z2 * 26), 'w': d3}
# 12
# mul y 0
# {'x': 1, 'y': 0, 'z': (z2 * 26), 'w': d3}
# 13
# add y w
# {'x': 1, 'y': d3, 'z': (z2 * 26), 'w': d3}
# 14
# add y 2
# {'x': 1, 'y': (d3 + 2), 'z': (z2 * 26), 'w': d3}
# 15
# mul y x
# {'x': 1, 'y': (d3 + 2), 'z': (z2 * 26), 'w': d3}
# 16
# add z y
# {'x': 1, 'y': (d3 + 2), 'z': ((z2 * 26) + (d3 + 2)), 'w': d3}
#
#
# --Block num 3--
# 0
# mul x 0
# {'x': 0, 'y': y3, 'z': z3, 'w': d4}
# 1
# add x z
# {'x': z3, 'y': y3, 'z': z3, 'w': d4}
# 2
# mod x 26
# {'x': (z3 % 26), 'y': y3, 'z': z3, 'w': d4}
# 3
# div z 1
# {'x': (z3 % 26), 'y': y3, 'z': z3, 'w': d4}
# 4
# add x 12
# {'x': ((z3 % 26) + 12), 'y': y3, 'z': z3, 'w': d4}
# mod plus too large equals digit
# 5
# eql x w
# {'x': 0, 'y': y3, 'z': z3, 'w': d4}
# 6
# eql x 0
# {'x': 1, 'y': y3, 'z': z3, 'w': d4}
# 7
# mul y 0
# {'x': 1, 'y': 0, 'z': z3, 'w': d4}
# 8
# add y 25
# {'x': 1, 'y': 25, 'z': z3, 'w': d4}
# 9
# mul y x
# {'x': 1, 'y': 25, 'z': z3, 'w': d4}
# 10
# add y 1
# {'x': 1, 'y': 26, 'z': z3, 'w': d4}
# 11
# mul z y
# {'x': 1, 'y': 26, 'z': (z3 * 26), 'w': d4}
# 12
# mul y 0
# {'x': 1, 'y': 0, 'z': (z3 * 26), 'w': d4}
# 13
# add y w
# {'x': 1, 'y': d4, 'z': (z3 * 26), 'w': d4}
# 14
# add y 11
# {'x': 1, 'y': (d4 + 11), 'z': (z3 * 26), 'w': d4}
# 15
# mul y x
# {'x': 1, 'y': (d4 + 11), 'z': (z3 * 26), 'w': d4}
# 16
# add z y
# {'x': 1, 'y': (d4 + 11), 'z': ((z3 * 26) + (d4 + 11)), 'w': d4}
#
#
# --Block num 4--
# 0
# mul x 0
# {'x': 0, 'y': y4, 'z': z4, 'w': d5}
# 1
# add x z
# {'x': z4, 'y': y4, 'z': z4, 'w': d5}
# 2
# mod x 26
# {'x': (z4 % 26), 'y': y4, 'z': z4, 'w': d5}
# 3
# div z 26
# {'x': (z4 % 26), 'y': y4, 'z': (z4 // 26), 'w': d5}
# 4
# add x -3
# {'x': ((z4 % 26) + -3), 'y': y4, 'z': (z4 // 26), 'w': d5}
# mod plus too large equals digit
# 5
# eql x w
# {'x': (((z4 % 26) + -3) == d5), 'y': y4, 'z': (z4 // 26), 'w': d5}
# 6
# eql x 0
# {'x': ((((z4 % 26) + -3) == d5) == 0), 'y': y4, 'z': (z4 // 26), 'w': d5}
# 7
# mul y 0
# {'x': ((((z4 % 26) + -3) == d5) == 0), 'y': 0, 'z': (z4 // 26), 'w': d5}
# 8
# add y 25
# {'x': ((((z4 % 26) + -3) == d5) == 0), 'y': 25, 'z': (z4 // 26), 'w': d5}
# 9
# mul y x
# {'x': ((((z4 % 26) + -3) == d5) == 0), 'y': (25 * ((((z4 % 26) + -3) == d5) == 0)), 'z': (z4 // 26), 'w': d5}
# 10
# add y 1
# {'x': ((((z4 % 26) + -3) == d5) == 0), 'y': ((25 * ((((z4 % 26) + -3) == d5) == 0)) + 1), 'z': (z4 // 26), 'w': d5}
# 11
# mul z y
# {'x': ((((z4 % 26) + -3) == d5) == 0), 'y': ((25 * ((((z4 % 26) + -3) == d5) == 0)) + 1), 'z': ((z4 // 26) * ((25 * ((((z4 % 26) + -3) == d5) == 0)) + 1)), 'w': d5}
# 12
# mul y 0
# {'x': ((((z4 % 26) + -3) == d5) == 0), 'y': 0, 'z': ((z4 // 26) * ((25 * ((((z4 % 26) + -3) == d5) == 0)) + 1)), 'w': d5}
# 13
# add y w
# {'x': ((((z4 % 26) + -3) == d5) == 0), 'y': d5, 'z': ((z4 // 26) * ((25 * ((((z4 % 26) + -3) == d5) == 0)) + 1)), 'w': d5}
# 14
# add y 6
# {'x': ((((z4 % 26) + -3) == d5) == 0), 'y': (d5 + 6), 'z': ((z4 // 26) * ((25 * ((((z4 % 26) + -3) == d5) == 0)) + 1)), 'w': d5}
# 15
# mul y x
# {'x': ((((z4 % 26) + -3) == d5) == 0), 'y': ((d5 + 6) * ((((z4 % 26) + -3) == d5) == 0)), 'z': ((z4 // 26) * ((25 * ((((z4 % 26) + -3) == d5) == 0)) + 1)), 'w': d5}
# 16
# add z y
# {'x': ((((z4 % 26) + -3) == d5) == 0), 'y': ((d5 + 6) * ((((z4 % 26) + -3) == d5) == 0)), 'z': (((z4 // 26) * ((25 * ((((z4 % 26) + -3) == d5) == 0)) + 1)) + ((d5 + 6) * ((((z4 % 26) + -3) == d5) == 0))), 'w': d5}
#
#
# --Block num 5--
# 0
# mul x 0
# {'x': 0, 'y': y5, 'z': z5, 'w': d6}
# 1
# add x z
# {'x': z5, 'y': y5, 'z': z5, 'w': d6}
# 2
# mod x 26
# {'x': (z5 % 26), 'y': y5, 'z': z5, 'w': d6}
# 3
# div z 1
# {'x': (z5 % 26), 'y': y5, 'z': z5, 'w': d6}
# 4
# add x 10
# {'x': ((z5 % 26) + 10), 'y': y5, 'z': z5, 'w': d6}
# mod plus too large equals digit
# 5
# eql x w
# {'x': 0, 'y': y5, 'z': z5, 'w': d6}
# 6
# eql x 0
# {'x': 1, 'y': y5, 'z': z5, 'w': d6}
# 7
# mul y 0
# {'x': 1, 'y': 0, 'z': z5, 'w': d6}
# 8
# add y 25
# {'x': 1, 'y': 25, 'z': z5, 'w': d6}
# 9
# mul y x
# {'x': 1, 'y': 25, 'z': z5, 'w': d6}
# 10
# add y 1
# {'x': 1, 'y': 26, 'z': z5, 'w': d6}
# 11
# mul z y
# {'x': 1, 'y': 26, 'z': (z5 * 26), 'w': d6}
# 12
# mul y 0
# {'x': 1, 'y': 0, 'z': (z5 * 26), 'w': d6}
# 13
# add y w
# {'x': 1, 'y': d6, 'z': (z5 * 26), 'w': d6}
# 14
# add y 12
# {'x': 1, 'y': (d6 + 12), 'z': (z5 * 26), 'w': d6}
# 15
# mul y x
# {'x': 1, 'y': (d6 + 12), 'z': (z5 * 26), 'w': d6}
# 16
# add z y
# {'x': 1, 'y': (d6 + 12), 'z': ((z5 * 26) + (d6 + 12)), 'w': d6}
#
#
# --Block num 6--
# 0
# mul x 0
# {'x': 0, 'y': y6, 'z': z6, 'w': d7}
# 1
# add x z
# {'x': z6, 'y': y6, 'z': z6, 'w': d7}
# 2
# mod x 26
# {'x': (z6 % 26), 'y': y6, 'z': z6, 'w': d7}
# 3
# div z 1
# {'x': (z6 % 26), 'y': y6, 'z': z6, 'w': d7}
# 4
# add x 14
# {'x': ((z6 % 26) + 14), 'y': y6, 'z': z6, 'w': d7}
# mod plus too large equals digit
# 5
# eql x w
# {'x': 0, 'y': y6, 'z': z6, 'w': d7}
# 6
# eql x 0
# {'x': 1, 'y': y6, 'z': z6, 'w': d7}
# 7
# mul y 0
# {'x': 1, 'y': 0, 'z': z6, 'w': d7}
# 8
# add y 25
# {'x': 1, 'y': 25, 'z': z6, 'w': d7}
# 9
# mul y x
# {'x': 1, 'y': 25, 'z': z6, 'w': d7}
# 10
# add y 1
# {'x': 1, 'y': 26, 'z': z6, 'w': d7}
# 11
# mul z y
# {'x': 1, 'y': 26, 'z': (z6 * 26), 'w': d7}
# 12
# mul y 0
# {'x': 1, 'y': 0, 'z': (z6 * 26), 'w': d7}
# 13
# add y w
# {'x': 1, 'y': d7, 'z': (z6 * 26), 'w': d7}
# 14
# add y 14
# {'x': 1, 'y': (d7 + 14), 'z': (z6 * 26), 'w': d7}
# 15
# mul y x
# {'x': 1, 'y': (d7 + 14), 'z': (z6 * 26), 'w': d7}
# 16
# add z y
# {'x': 1, 'y': (d7 + 14), 'z': ((z6 * 26) + (d7 + 14)), 'w': d7}
#
#
# --Block num 7--
# 0
# mul x 0
# {'x': 0, 'y': y7, 'z': z7, 'w': d8}
# 1
# add x z
# {'x': z7, 'y': y7, 'z': z7, 'w': d8}
# 2
# mod x 26
# {'x': (z7 % 26), 'y': y7, 'z': z7, 'w': d8}
# 3
# div z 26
# {'x': (z7 % 26), 'y': y7, 'z': (z7 // 26), 'w': d8}
# 4
# add x -16
# {'x': ((z7 % 26) + -16), 'y': y7, 'z': (z7 // 26), 'w': d8}
# mod plus too large equals digit
# 5
# eql x w
# {'x': (((z7 % 26) + -16) == d8), 'y': y7, 'z': (z7 // 26), 'w': d8}
# 6
# eql x 0
# {'x': ((((z7 % 26) + -16) == d8) == 0), 'y': y7, 'z': (z7 // 26), 'w': d8}
# 7
# mul y 0
# {'x': ((((z7 % 26) + -16) == d8) == 0), 'y': 0, 'z': (z7 // 26), 'w': d8}
# 8
# add y 25
# {'x': ((((z7 % 26) + -16) == d8) == 0), 'y': 25, 'z': (z7 // 26), 'w': d8}
# 9
# mul y x
# {'x': ((((z7 % 26) + -16) == d8) == 0), 'y': (25 * ((((z7 % 26) + -16) == d8) == 0)), 'z': (z7 // 26), 'w': d8}
# 10
# add y 1
# {'x': ((((z7 % 26) + -16) == d8) == 0), 'y': ((25 * ((((z7 % 26) + -16) == d8) == 0)) + 1), 'z': (z7 // 26), 'w': d8}
# 11
# mul z y
# {'x': ((((z7 % 26) + -16) == d8) == 0), 'y': ((25 * ((((z7 % 26) + -16) == d8) == 0)) + 1), 'z': ((z7 // 26) * ((25 * ((((z7 % 26) + -16) == d8) == 0)) + 1)), 'w': d8}
# 12
# mul y 0
# {'x': ((((z7 % 26) + -16) == d8) == 0), 'y': 0, 'z': ((z7 // 26) * ((25 * ((((z7 % 26) + -16) == d8) == 0)) + 1)), 'w': d8}
# 13
# add y w
# {'x': ((((z7 % 26) + -16) == d8) == 0), 'y': d8, 'z': ((z7 // 26) * ((25 * ((((z7 % 26) + -16) == d8) == 0)) + 1)), 'w': d8}
# 14
# add y 13
# {'x': ((((z7 % 26) + -16) == d8) == 0), 'y': (d8 + 13), 'z': ((z7 // 26) * ((25 * ((((z7 % 26) + -16) == d8) == 0)) + 1)), 'w': d8}
# 15
# mul y x
# {'x': ((((z7 % 26) + -16) == d8) == 0), 'y': ((d8 + 13) * ((((z7 % 26) + -16) == d8) == 0)), 'z': ((z7 // 26) * ((25 * ((((z7 % 26) + -16) == d8) == 0)) + 1)), 'w': d8}
# 16
# add z y
# {'x': ((((z7 % 26) + -16) == d8) == 0), 'y': ((d8 + 13) * ((((z7 % 26) + -16) == d8) == 0)), 'z': (((z7 // 26) * ((25 * ((((z7 % 26) + -16) == d8) == 0)) + 1)) + ((d8 + 13) * ((((z7 % 26) + -16) == d8) == 0))), 'w': d8}
#
#
# --Block num 8--
# 0
# mul x 0
# {'x': 0, 'y': y8, 'z': z8, 'w': d9}
# 1
# add x z
# {'x': z8, 'y': y8, 'z': z8, 'w': d9}
# 2
# mod x 26
# {'x': (z8 % 26), 'y': y8, 'z': z8, 'w': d9}
# 3
# div z 1
# {'x': (z8 % 26), 'y': y8, 'z': z8, 'w': d9}
# 4
# add x 12
# {'x': ((z8 % 26) + 12), 'y': y8, 'z': z8, 'w': d9}
# mod plus too large equals digit
# 5
# eql x w
# {'x': 0, 'y': y8, 'z': z8, 'w': d9}
# 6
# eql x 0
# {'x': 1, 'y': y8, 'z': z8, 'w': d9}
# 7
# mul y 0
# {'x': 1, 'y': 0, 'z': z8, 'w': d9}
# 8
# add y 25
# {'x': 1, 'y': 25, 'z': z8, 'w': d9}
# 9
# mul y x
# {'x': 1, 'y': 25, 'z': z8, 'w': d9}
# 10
# add y 1
# {'x': 1, 'y': 26, 'z': z8, 'w': d9}
# 11
# mul z y
# {'x': 1, 'y': 26, 'z': (z8 * 26), 'w': d9}
# 12
# mul y 0
# {'x': 1, 'y': 0, 'z': (z8 * 26), 'w': d9}
# 13
# add y w
# {'x': 1, 'y': d9, 'z': (z8 * 26), 'w': d9}
# 14
# add y 15
# {'x': 1, 'y': (d9 + 15), 'z': (z8 * 26), 'w': d9}
# 15
# mul y x
# {'x': 1, 'y': (d9 + 15), 'z': (z8 * 26), 'w': d9}
# 16
# add z y
# {'x': 1, 'y': (d9 + 15), 'z': ((z8 * 26) + (d9 + 15)), 'w': d9}
#
#
# --Block num 9--
# 0
# mul x 0
# {'x': 0, 'y': y9, 'z': z9, 'w': d10}
# 1
# add x z
# {'x': z9, 'y': y9, 'z': z9, 'w': d10}
# 2
# mod x 26
# {'x': (z9 % 26), 'y': y9, 'z': z9, 'w': d10}
# 3
# div z 26
# {'x': (z9 % 26), 'y': y9, 'z': (z9 // 26), 'w': d10}
# 4
# add x -8
# {'x': ((z9 % 26) + -8), 'y': y9, 'z': (z9 // 26), 'w': d10}
# mod plus too large equals digit
# 5
# eql x w
# {'x': (((z9 % 26) + -8) == d10), 'y': y9, 'z': (z9 // 26), 'w': d10}
# 6
# eql x 0
# {'x': ((((z9 % 26) + -8) == d10) == 0), 'y': y9, 'z': (z9 // 26), 'w': d10}
# 7
# mul y 0
# {'x': ((((z9 % 26) + -8) == d10) == 0), 'y': 0, 'z': (z9 // 26), 'w': d10}
# 8
# add y 25
# {'x': ((((z9 % 26) + -8) == d10) == 0), 'y': 25, 'z': (z9 // 26), 'w': d10}
# 9
# mul y x
# {'x': ((((z9 % 26) + -8) == d10) == 0), 'y': (25 * ((((z9 % 26) + -8) == d10) == 0)), 'z': (z9 // 26), 'w': d10}
# 10
# add y 1
# {'x': ((((z9 % 26) + -8) == d10) == 0), 'y': ((25 * ((((z9 % 26) + -8) == d10) == 0)) + 1), 'z': (z9 // 26), 'w': d10}
# 11
# mul z y
# {'x': ((((z9 % 26) + -8) == d10) == 0), 'y': ((25 * ((((z9 % 26) + -8) == d10) == 0)) + 1), 'z': ((z9 // 26) * ((25 * ((((z9 % 26) + -8) == d10) == 0)) + 1)), 'w': d10}
# 12
# mul y 0
# {'x': ((((z9 % 26) + -8) == d10) == 0), 'y': 0, 'z': ((z9 // 26) * ((25 * ((((z9 % 26) + -8) == d10) == 0)) + 1)), 'w': d10}
# 13
# add y w
# {'x': ((((z9 % 26) + -8) == d10) == 0), 'y': d10, 'z': ((z9 // 26) * ((25 * ((((z9 % 26) + -8) == d10) == 0)) + 1)), 'w': d10}
# 14
# add y 10
# {'x': ((((z9 % 26) + -8) == d10) == 0), 'y': (d10 + 10), 'z': ((z9 // 26) * ((25 * ((((z9 % 26) + -8) == d10) == 0)) + 1)), 'w': d10}
# 15
# mul y x
# {'x': ((((z9 % 26) + -8) == d10) == 0), 'y': ((d10 + 10) * ((((z9 % 26) + -8) == d10) == 0)), 'z': ((z9 // 26) * ((25 * ((((z9 % 26) + -8) == d10) == 0)) + 1)), 'w': d10}
# 16
# add z y
# {'x': ((((z9 % 26) + -8) == d10) == 0), 'y': ((d10 + 10) * ((((z9 % 26) + -8) == d10) == 0)), 'z': (((z9 // 26) * ((25 * ((((z9 % 26) + -8) == d10) == 0)) + 1)) + ((d10 + 10) * ((((z9 % 26) + -8) == d10) == 0))), 'w': d10}
#
#
# --Block num 10--
# 0
# mul x 0
# {'x': 0, 'y': y10, 'z': z10, 'w': d11}
# 1
# add x z
# {'x': z10, 'y': y10, 'z': z10, 'w': d11}
# 2
# mod x 26
# {'x': (z10 % 26), 'y': y10, 'z': z10, 'w': d11}
# 3
# div z 26
# {'x': (z10 % 26), 'y': y10, 'z': (z10 // 26), 'w': d11}
# 4
# add x -12
# {'x': ((z10 % 26) + -12), 'y': y10, 'z': (z10 // 26), 'w': d11}
# mod plus too large equals digit
# 5
# eql x w
# {'x': (((z10 % 26) + -12) == d11), 'y': y10, 'z': (z10 // 26), 'w': d11}
# 6
# eql x 0
# {'x': ((((z10 % 26) + -12) == d11) == 0), 'y': y10, 'z': (z10 // 26), 'w': d11}
# 7
# mul y 0
# {'x': ((((z10 % 26) + -12) == d11) == 0), 'y': 0, 'z': (z10 // 26), 'w': d11}
# 8
# add y 25
# {'x': ((((z10 % 26) + -12) == d11) == 0), 'y': 25, 'z': (z10 // 26), 'w': d11}
# 9
# mul y x
# {'x': ((((z10 % 26) + -12) == d11) == 0), 'y': (25 * ((((z10 % 26) + -12) == d11) == 0)), 'z': (z10 // 26), 'w': d11}
# 10
# add y 1
# {'x': ((((z10 % 26) + -12) == d11) == 0), 'y': ((25 * ((((z10 % 26) + -12) == d11) == 0)) + 1), 'z': (z10 // 26), 'w': d11}
# 11
# mul z y
# {'x': ((((z10 % 26) + -12) == d11) == 0), 'y': ((25 * ((((z10 % 26) + -12) == d11) == 0)) + 1), 'z': ((z10 // 26) * ((25 * ((((z10 % 26) + -12) == d11) == 0)) + 1)), 'w': d11}
# 12
# mul y 0
# {'x': ((((z10 % 26) + -12) == d11) == 0), 'y': 0, 'z': ((z10 // 26) * ((25 * ((((z10 % 26) + -12) == d11) == 0)) + 1)), 'w': d11}
# 13
# add y w
# {'x': ((((z10 % 26) + -12) == d11) == 0), 'y': d11, 'z': ((z10 // 26) * ((25 * ((((z10 % 26) + -12) == d11) == 0)) + 1)), 'w': d11}
# 14
# add y 6
# {'x': ((((z10 % 26) + -12) == d11) == 0), 'y': (d11 + 6), 'z': ((z10 // 26) * ((25 * ((((z10 % 26) + -12) == d11) == 0)) + 1)), 'w': d11}
# 15
# mul y x
# {'x': ((((z10 % 26) + -12) == d11) == 0), 'y': ((d11 + 6) * ((((z10 % 26) + -12) == d11) == 0)), 'z': ((z10 // 26) * ((25 * ((((z10 % 26) + -12) == d11) == 0)) + 1)), 'w': d11}
# 16
# add z y
# {'x': ((((z10 % 26) + -12) == d11) == 0), 'y': ((d11 + 6) * ((((z10 % 26) + -12) == d11) == 0)), 'z': (((z10 // 26) * ((25 * ((((z10 % 26) + -12) == d11) == 0)) + 1)) + ((d11 + 6) * ((((z10 % 26) + -12) == d11) == 0))), 'w': d11}
#
#
# --Block num 11--
# 0
# mul x 0
# {'x': 0, 'y': y11, 'z': z11, 'w': d12}
# 1
# add x z
# {'x': z11, 'y': y11, 'z': z11, 'w': d12}
# 2
# mod x 26
# {'x': (z11 % 26), 'y': y11, 'z': z11, 'w': d12}
# 3
# div z 26
# {'x': (z11 % 26), 'y': y11, 'z': (z11 // 26), 'w': d12}
# 4
# add x -7
# {'x': ((z11 % 26) + -7), 'y': y11, 'z': (z11 // 26), 'w': d12}
# mod plus too large equals digit
# 5
# eql x w
# {'x': (((z11 % 26) + -7) == d12), 'y': y11, 'z': (z11 // 26), 'w': d12}
# 6
# eql x 0
# {'x': ((((z11 % 26) + -7) == d12) == 0), 'y': y11, 'z': (z11 // 26), 'w': d12}
# 7
# mul y 0
# {'x': ((((z11 % 26) + -7) == d12) == 0), 'y': 0, 'z': (z11 // 26), 'w': d12}
# 8
# add y 25
# {'x': ((((z11 % 26) + -7) == d12) == 0), 'y': 25, 'z': (z11 // 26), 'w': d12}
# 9
# mul y x
# {'x': ((((z11 % 26) + -7) == d12) == 0), 'y': (25 * ((((z11 % 26) + -7) == d12) == 0)), 'z': (z11 // 26), 'w': d12}
# 10
# add y 1
# {'x': ((((z11 % 26) + -7) == d12) == 0), 'y': ((25 * ((((z11 % 26) + -7) == d12) == 0)) + 1), 'z': (z11 // 26), 'w': d12}
# 11
# mul z y
# {'x': ((((z11 % 26) + -7) == d12) == 0), 'y': ((25 * ((((z11 % 26) + -7) == d12) == 0)) + 1), 'z': ((z11 // 26) * ((25 * ((((z11 % 26) + -7) == d12) == 0)) + 1)), 'w': d12}
# 12
# mul y 0
# {'x': ((((z11 % 26) + -7) == d12) == 0), 'y': 0, 'z': ((z11 // 26) * ((25 * ((((z11 % 26) + -7) == d12) == 0)) + 1)), 'w': d12}
# 13
# add y w
# {'x': ((((z11 % 26) + -7) == d12) == 0), 'y': d12, 'z': ((z11 // 26) * ((25 * ((((z11 % 26) + -7) == d12) == 0)) + 1)), 'w': d12}
# 14
# add y 10
# {'x': ((((z11 % 26) + -7) == d12) == 0), 'y': (d12 + 10), 'z': ((z11 // 26) * ((25 * ((((z11 % 26) + -7) == d12) == 0)) + 1)), 'w': d12}
# 15
# mul y x
# {'x': ((((z11 % 26) + -7) == d12) == 0), 'y': ((d12 + 10) * ((((z11 % 26) + -7) == d12) == 0)), 'z': ((z11 // 26) * ((25 * ((((z11 % 26) + -7) == d12) == 0)) + 1)), 'w': d12}
# 16
# add z y
# {'x': ((((z11 % 26) + -7) == d12) == 0), 'y': ((d12 + 10) * ((((z11 % 26) + -7) == d12) == 0)), 'z': (((z11 // 26) * ((25 * ((((z11 % 26) + -7) == d12) == 0)) + 1)) + ((d12 + 10) * ((((z11 % 26) + -7) == d12) == 0))), 'w': d12}
#
#
# --Block num 12--
# 0
# mul x 0
# {'x': 0, 'y': y12, 'z': z12, 'w': d13}
# 1
# add x z
# {'x': z12, 'y': y12, 'z': z12, 'w': d13}
# 2
# mod x 26
# {'x': (z12 % 26), 'y': y12, 'z': z12, 'w': d13}
# 3
# div z 26
# {'x': (z12 % 26), 'y': y12, 'z': (z12 // 26), 'w': d13}
# 4
# add x -6
# {'x': ((z12 % 26) + -6), 'y': y12, 'z': (z12 // 26), 'w': d13}
# mod plus too large equals digit
# 5
# eql x w
# {'x': (((z12 % 26) + -6) == d13), 'y': y12, 'z': (z12 // 26), 'w': d13}
# 6
# eql x 0
# {'x': ((((z12 % 26) + -6) == d13) == 0), 'y': y12, 'z': (z12 // 26), 'w': d13}
# 7
# mul y 0
# {'x': ((((z12 % 26) + -6) == d13) == 0), 'y': 0, 'z': (z12 // 26), 'w': d13}
# 8
# add y 25
# {'x': ((((z12 % 26) + -6) == d13) == 0), 'y': 25, 'z': (z12 // 26), 'w': d13}
# 9
# mul y x
# {'x': ((((z12 % 26) + -6) == d13) == 0), 'y': (25 * ((((z12 % 26) + -6) == d13) == 0)), 'z': (z12 // 26), 'w': d13}
# 10
# add y 1
# {'x': ((((z12 % 26) + -6) == d13) == 0), 'y': ((25 * ((((z12 % 26) + -6) == d13) == 0)) + 1), 'z': (z12 // 26), 'w': d13}
# 11
# mul z y
# {'x': ((((z12 % 26) + -6) == d13) == 0), 'y': ((25 * ((((z12 % 26) + -6) == d13) == 0)) + 1), 'z': ((z12 // 26) * ((25 * ((((z12 % 26) + -6) == d13) == 0)) + 1)), 'w': d13}
# 12
# mul y 0
# {'x': ((((z12 % 26) + -6) == d13) == 0), 'y': 0, 'z': ((z12 // 26) * ((25 * ((((z12 % 26) + -6) == d13) == 0)) + 1)), 'w': d13}
# 13
# add y w
# {'x': ((((z12 % 26) + -6) == d13) == 0), 'y': d13, 'z': ((z12 // 26) * ((25 * ((((z12 % 26) + -6) == d13) == 0)) + 1)), 'w': d13}
# 14
# add y 8
# {'x': ((((z12 % 26) + -6) == d13) == 0), 'y': (d13 + 8), 'z': ((z12 // 26) * ((25 * ((((z12 % 26) + -6) == d13) == 0)) + 1)), 'w': d13}
# 15
# mul y x
# {'x': ((((z12 % 26) + -6) == d13) == 0), 'y': ((d13 + 8) * ((((z12 % 26) + -6) == d13) == 0)), 'z': ((z12 // 26) * ((25 * ((((z12 % 26) + -6) == d13) == 0)) + 1)), 'w': d13}
# 16
# add z y
# {'x': ((((z12 % 26) + -6) == d13) == 0), 'y': ((d13 + 8) * ((((z12 % 26) + -6) == d13) == 0)), 'z': (((z12 // 26) * ((25 * ((((z12 % 26) + -6) == d13) == 0)) + 1)) + ((d13 + 8) * ((((z12 % 26) + -6) == d13) == 0))), 'w': d13}
#
#
# --Block num 13--
# 0
# mul x 0
# {'x': 0, 'y': y13, 'z': z13, 'w': d14}
# 1
# add x z
# {'x': z13, 'y': y13, 'z': z13, 'w': d14}
# 2
# mod x 26
# {'x': (z13 % 26), 'y': y13, 'z': z13, 'w': d14}
# 3
# div z 26
# {'x': (z13 % 26), 'y': y13, 'z': (z13 // 26), 'w': d14}
# 4
# add x -11
# {'x': ((z13 % 26) + -11), 'y': y13, 'z': (z13 // 26), 'w': d14}
# mod plus too large equals digit
# 5
# eql x w
# {'x': (((z13 % 26) + -11) == d14), 'y': y13, 'z': (z13 // 26), 'w': d14}
# 6
# eql x 0
# {'x': ((((z13 % 26) + -11) == d14) == 0), 'y': y13, 'z': (z13 // 26), 'w': d14}
# 7
# mul y 0
# {'x': ((((z13 % 26) + -11) == d14) == 0), 'y': 0, 'z': (z13 // 26), 'w': d14}
# 8
# add y 25
# {'x': ((((z13 % 26) + -11) == d14) == 0), 'y': 25, 'z': (z13 // 26), 'w': d14}
# 9
# mul y x
# {'x': ((((z13 % 26) + -11) == d14) == 0), 'y': (25 * ((((z13 % 26) + -11) == d14) == 0)), 'z': (z13 // 26), 'w': d14}
# 10
# add y 1
# {'x': ((((z13 % 26) + -11) == d14) == 0), 'y': ((25 * ((((z13 % 26) + -11) == d14) == 0)) + 1), 'z': (z13 // 26), 'w': d14}
# 11
# mul z y
# {'x': ((((z13 % 26) + -11) == d14) == 0), 'y': ((25 * ((((z13 % 26) + -11) == d14) == 0)) + 1), 'z': ((z13 // 26) * ((25 * ((((z13 % 26) + -11) == d14) == 0)) + 1)), 'w': d14}
# 12
# mul y 0
# {'x': ((((z13 % 26) + -11) == d14) == 0), 'y': 0, 'z': ((z13 // 26) * ((25 * ((((z13 % 26) + -11) == d14) == 0)) + 1)), 'w': d14}
# 13
# add y w
# {'x': ((((z13 % 26) + -11) == d14) == 0), 'y': d14, 'z': ((z13 // 26) * ((25 * ((((z13 % 26) + -11) == d14) == 0)) + 1)), 'w': d14}
# 14
# add y 5
# {'x': ((((z13 % 26) + -11) == d14) == 0), 'y': (d14 + 5), 'z': ((z13 // 26) * ((25 * ((((z13 % 26) + -11) == d14) == 0)) + 1)), 'w': d14}
# 15
# mul y x
# {'x': ((((z13 % 26) + -11) == d14) == 0), 'y': ((d14 + 5) * ((((z13 % 26) + -11) == d14) == 0)), 'z': ((z13 // 26) * ((25 * ((((z13 % 26) + -11) == d14) == 0)) + 1)), 'w': d14}
# 16
# add z y
# {'x': ((((z13 % 26) + -11) == d14) == 0), 'y': ((d14 + 5) * ((((z13 % 26) + -11) == d14) == 0)), 'z': (((z13 // 26) * ((25 * ((((z13 % 26) + -11) == d14) == 0)) + 1)) + ((d14 + 5) * ((((z13 % 26) + -11) == d14) == 0))), 'w': d14}

# %%
for i, fe in enumerate(final_expressions):
    print(f'z{i+1} =', fe['z'])
# Out:
# z1 = (d1 + 7)
# z2 = ((z1 * 26) + (d2 + 8))
# z3 = ((z2 * 26) + (d3 + 2))
# z4 = ((z3 * 26) + (d4 + 11))
# z5 = (((z4 // 26) * ((25 * ((((z4 % 26) + -3) == d5) == 0)) + 1)) + ((d5 + 6) * ((((z4 % 26) + -3) == d5) == 0)))
# z6 = ((z5 * 26) + (d6 + 12))
# z7 = ((z6 * 26) + (d7 + 14))
# z8 = (((z7 // 26) * ((25 * ((((z7 % 26) + -16) == d8) == 0)) + 1)) + ((d8 + 13) * ((((z7 % 26) + -16) == d8) == 0)))
# z9 = ((z8 * 26) + (d9 + 15))
# z10 = (((z9 // 26) * ((25 * ((((z9 % 26) + -8) == d10) == 0)) + 1)) + ((d10 + 10) * ((((z9 % 26) + -8) == d10) == 0)))
# z11 = (((z10 // 26) * ((25 * ((((z10 % 26) + -12) == d11) == 0)) + 1)) + ((d11 + 6) * ((((z10 % 26) + -12) == d11) == 0)))
# z12 = (((z11 // 26) * ((25 * ((((z11 % 26) + -7) == d12) == 0)) + 1)) + ((d12 + 10) * ((((z11 % 26) + -7) == d12) == 0)))
# z13 = (((z12 // 26) * ((25 * ((((z12 % 26) + -6) == d13) == 0)) + 1)) + ((d13 + 8) * ((((z12 % 26) + -6) == d13) == 0)))
# z14 = (((z13 // 26) * ((25 * ((((z13 % 26) + -11) == d14) == 0)) + 1)) + ((d14 + 5) * ((((z13 % 26) + -11) == d14) == 0)))

# %% [markdown]
# therefore
# d1+7 = d14+11
#
# z1 = d1+7
# z1 = d14+11
#
# d2+8 = d13+6
#
# but we know, therefore^
# z2 = ((z1 * 26) + (d2 + 8))
#
# z2 = 26*(d14+11) + d13 + 6
# d3+2 = d12+7
#
# but we know, therefore^
# z3 = ((z2 * 26) + (d3 + 2))
#
# z3 = 26*(26*(d14+11) + d13 + 6) + d12 + 7
# d4+11 = d5+3
#
# but we know, therefore^
# z4 = ((z3 * 26) + (d4 + 11))
#
# z4 = 26*(26*(26*(d14+11) + d13 + 6) + d12 + 7) + d5 + 3
# z5 = 26*(26*(d14+11) + d13 + 6) + d12 + 7
# d6+12 = d11+12
#
# but we know, therefore^
# z6 = ((z5 * 26) + (d6 + 12))
#
# z6 = 26*(26*(26*(d14+11) + d13 + 6) + d12 + 7) + d11+ 12
# d7+14 = d8 + 16
#
# but we know
# z7 = ((z6 * 26) + (d7 + 14)), therefore^
#
# z7 = 26*(26*(26*(26*(d14+11) + d13 + 6) + d12 + 7) + d11+ 12) + d8 + 16
# z8 = 26*(26*(26*(d14+11) + d13 + 6) + d12 + 7) + d11+ 12
# d9 + 15 = d10 + 8
#
# but we know
# z9 = ((z8 * 26) + (d9 + 15)), therefore ^
#
# z9 = 26*(26*(26*(26*(d14+11) + d13 + 6) + d12 + 7) + d11+ 12) + d10 + 8
# z10 = 26*(26*(26*(d14+11) + d13 + 6) + d12 + 7) + d11 + 12
# z11 = 26*(26*(d14+11) + d13 + 6) + d12 + 7
# z12 = 26*(d14+11) + d13 + 6
# z13 = d14 + 11
# z14 = 0

# %% [markdown]
# d1+7 = d14+11
# d2+8 = d13+6
# d3+2 = d12+7
# d4+11 = d5+3
# d6+12 = d11+12
# d7+14 = d8+16
# d9+15 = d10+8

# %% [markdown]
# d14 = d1-4
# d13 = d2+2
# d12 = d3-5
# d5 = d4+8
# d11 = d6
# d8 = d7-2
# d10 = d9+7

# %%
# minimize

d1 = 5
d14 = 1

d2 = 1
d13 = 3

d3 = 6
d12 = 1

d4 = 1
d5 = 9

d6 = 1
d11 = 1

d7 = 3
d8 = 1

d9 = 1
d10 = 8

# %% [markdown]
# # maximize
#
# d1 = 9
# d14 = 5
#
# d2 = 7
# d13 = 9
#
# d3 = 9
# d12 = 4
#
# d4 = 1
# d5 = 9
#
# d6 = 9
# d11 = 9
#
# d7 = 9
# d8 = 7
#
# d9 = 2
# d10 = 9

# %%
z1 = eval(str(final_expressions[0]['z']))
z2 = eval(str(final_expressions[1]['z']))
z3 = eval(str(final_expressions[2]['z']))
z4 = eval(str(final_expressions[3]['z']))
z5 = eval(str(final_expressions[4]['z']))
z6 = eval(str(final_expressions[5]['z']))
z7 = eval(str(final_expressions[6]['z']))
z8 = eval(str(final_expressions[7]['z']))
z9 = eval(str(final_expressions[8]['z']))
z10 = eval(str(final_expressions[9]['z']))
z11 = eval(str(final_expressions[10]['z']))
z12 = eval(str(final_expressions[11]['z']))
z13 = eval(str(final_expressions[12]['z']))
z14 = eval(str(final_expressions[13]['z']))

assert z14 == 0
