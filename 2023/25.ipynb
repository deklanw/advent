# %%
import networkx as nx
import numpy as np

# %%
test_input = """jqt: rhn xhk nvd
rsh: frs pzl lsr
xhk: hfx
cmg: qnr nvd lhk bvb
rhn: xhk bvb hfx
bvb: xhk hfx
pzl: lsr hfx nvd
qnr: nvd
ntq: jqt hfx bvb xhk
nvd: lhk
lsr: lhk
rzs: qnr cmg lsr rsh
frs: qnr lhk lsr"""

# %%
input = open("inputs/25").read()

# %%
g = nx.Graph()

# for l in test_input.splitlines():
for l in input.splitlines():
    source, targets = l.split(":")
    targets = targets.split()

    # print(source, targets)

    for t in targets:
        g.add_edge(source, t)

# %%
g

# %%
from networkx.drawing.nx_agraph import to_agraph 


A = to_agraph(g)
A

# for node in A.nodes():
#     # node.attr['label'] = 'Custom Label'  # Set a custom label

#     module_type = node.attr['module_type']
#     node.attr['color'] = 'red' if module_type == '%' else 'blue' if module_type == '&' else 'black'

# for edge in A.edges():
#     edge.attr['label'] = edge.attr['index']

# A.layout()
# A.draw('25_graph_test.png', prog='dot')  # Save to file
# Out:
# <AGraph <Swig Object of type 'Agraph_t *' at 0x7f37ece41560>>

# %%
to_delete = nx.minimum_edge_cut(g)

# %%
g.remove_edges_from(to_delete)

# %%
cc = list(nx.connected_components(g))

# %%
import math

math.prod((len(c) for c in cc))
# Out:
# 568214
